# %%
# Подавление предупреждений
import warnings
for warn in [UserWarning, FutureWarning]: warnings.filterwarnings("ignore", category = warn)

# Импорт необходимых библиотек
import os
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
from tqdm import tqdm

from transformers import AutoTokenizer, AutoModel,AutoModelForMaskedLM, RobertaModel, RobertaTokenizer
import torch
import torch.nn.functional as F
from torch import Tensor
from einops import rearrange
from typing import Tuple, Callable
from torch.autograd import Function
import gc
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Данные

# %%
from torch.utils.data import Dataset, DataLoader 
import numpy as np 
import math 

class RESDDataset(): 
    def __init__(self, part='train'): 
        if part == 'train':
            df = pd.read_csv("train.csv")
        elif part == 'test':
            df = pd.read_csv("test.csv")
        else:
            raise ValueError('Unknown part of RESDDataset (train / test)')
        self.x = list(df['text'].values)
        transform_dict = {'anger' : 0, 'disgust' : 1, 'fear' : 2, 'sadness' : 3, 'neutral' : 4, 'happiness' : 5, 'enthusiasm' : 6}
        self.y = torch.tensor(df['emotion'].apply(lambda x : transform_dict[x])).to(device)
        self.n_samples = df.shape[0]  

    def __getitem__(self, index): 
        return self.x[index], self.y[index] 
        
    def __len__(self): 
        return self.n_samples

# %% [markdown]
# ### Feature Extractor

# %%
class Embedding():
    def __init__(self, model_name='jina', pooling=None):
        self.model_name = model_name
        self.pooling = pooling
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        if model_name == 'jina':
            self.tokenizer = AutoTokenizer.from_pretrained("jinaai/jina-embeddings-v3", code_revision='da863dd04a4e5dce6814c6625adfba87b83838aa', trust_remote_code=True)
            self.model = AutoModel.from_pretrained("jinaai/jina-embeddings-v3", code_revision='da863dd04a4e5dce6814c6625adfba87b83838aa', trust_remote_code=True).to(self.device)
        elif model_name == 'xlm-roberta-base':
            self.tokenizer = AutoTokenizer.from_pretrained('xlm-roberta-base')
            self.model = AutoModel.from_pretrained('xlm-roberta-base').to(self.device)
        elif model_name == 'canine-c':
            self.tokenizer = AutoTokenizer.from_pretrained('google/canine-c')
            self.model = AutoModel.from_pretrained('google/canine-c').to(self.device)
        else:
            raise ValueError('Unknown name of Embedding')
    def _mean_pooling(self, X):
        def mean_pooling(model_output, attention_mask):
            token_embeddings = model_output[0]
            input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
            return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)
        encoded_input = self.tokenizer(X, padding=True, truncation=True, return_tensors='pt').to(self.device)
        with torch.no_grad():
            model_output = self.model(**encoded_input)
        sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
        sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)
        return sentence_embeddings.unsqueeze(1)
    
    def get_embeddings(self, X):
        if self.pooling is None:
            if self.model_name == 'canine-c_emb':
                max_len = 300
            else:
                max_len = 88
            encoded_input = self.tokenizer(X, padding=True, truncation=True, return_tensors='pt').to(self.device)
            with torch.no_grad():
                features = self.model(**encoded_input)[0].detach().cpu().float().numpy()
            res = np.pad(features[:, :max_len, :], ((0, 0), (0, max(0, max_len - features.shape[1])), (0, 0)), "constant")
            return torch.tensor(res)
        elif self.pooling == 'mean':
            return self._mean_pooling(X)
        else:
            raise ValueError('Unknown type of pooling')

# %% [markdown]
# # Обучение

# %%
from dataclasses import dataclass
from typing import ClassVar
from typing import List, Dict, Any, Tuple, Optional
@dataclass
class ModelTrainer:
    model: 'typing.Any'
    train_dataloader: DataLoader
    test_dataloader: DataLoader
    device: torch.device
    epochs: int
    round_loss: int
    round_acc: int

    optimizer: torch.optim
    loss_fn: 'typing.Any'
    
    patience: int = 5 # Ранняя остановка обучения

    class_names: ClassVar[Optional[List[str]]] = None # Список имен классов

    def __post_init__(self):
        
        # История обучения и тестирования
        self.__history = pd.DataFrame({
            "train_acc": [], # Точность на тренировочной выборке
            "test_acc": [], # Точность на тестовой выборке
            "train_loss": [], # Loss на тренировочной выборке
            "test_loss": [] # Loss на тестовой выборке
        })

        # Количество шагов в одной эпохе
        self.__train_steps = len(self.train_dataloader)
        self.__test_steps = len(self.test_dataloader)

        self.__best_test_accuracy = 0
        self.__no_improvement_count = 0
        
        self.loss_fn = self.loss_fn

    @property
    def history(self) -> pd.DataFrame:
        """Получение DataFrame историей обучения и тестирования

        Returns:
            pd.DataFrame: **DataFrame** c историей обучения и тестирования
        """

        return self.__history

    @classmethod
    def get_model_logits(cls, logits: torch.Tensor) -> torch.Tensor:
        """Получение логитов модели в зависимости от функции потерь

        Args:
            logits (torch.Tensor): Входные логиты

        Returns:
            torch.Tensor: Обработанные логиты
        """

        if isinstance(cls.loss_fn, nn.NLLLoss):
            log_softmax = nn.LogSoftmax(dim = 1)
            return log_softmax(logits)
        elif isinstance(cls.loss_fn, nn.CrossEntropyLoss):
            return logits

    def _is_best_model(self, test_accuracy: float) -> bool:
        """Проверка, является ли текущая модель лучшей на основе точности тестирования

        Args:
            test_accuracy (float): Текущая точность тестирования

        Returns:
            bool: True, если текущая модель лучшая, иначе False
        """

        try:
            max_test_acc = max(self.__history["test_acc"])
        except ValueError:
            max_test_acc = 0
        return test_accuracy > max_test_acc

    def _save_model(self, epoch: int, path_to_model: str, test_accuracy: float, loss: torch.Tensor) -> None:
        """Сохранение модели

        Args:
            epoch (int): Текущая эпоха
            path_to_model (str): Путь для сохранения модели
            test_accuracy (float): Точность на тестовой выборке
            loss (torch.Tensor): Значение потерь
        """
        
        os.makedirs(path_to_model, exist_ok = True)

        torch.save({
            "epoch": epoch,
            "model_state_dict": self.model.state_dict(),
            "optimizer_state_dict": self.optimizer.state_dict(),
            "test_loss": loss,
        }, os.path.join(path_to_model, f"{self.model.__class__.__name__}_{self.model.model_name}_{epoch}_{test_accuracy}_checkpoint.pth"))
    
    # Процесс обучения
    def train(self, path_to_model: str) -> None:
        """Процесс обучения

        Args:
            path_to_model (str): Путь для сохранения моделей

        Returns:
            None
        """
        
        losses_train_list = []
        losses_test_list = []
        accuracy_train_list = []
        accuracy_test_list = []

        for epoch in range(1, self.epochs + 1):
            with torch.no_grad():
                torch.cuda.empty_cache()
            self.model.train() # Установка модели в режим обучения
            # Сумма Loss
            total_train_loss = 0
            total_test_loss = 0
            # Сумма точности
            train_accuracy = 0
            test_accuracy = 0

            # Проход по всем тренировочным пакетам
            with tqdm(total = self.__train_steps, desc = f"Эпоха {epoch}", unit = "batch") as pbar_train:
                for batch, (batch_X, targets) in enumerate(self.train_dataloader, 1):
                    logits = self.model(batch_X)
                    loss = self.loss_fn(logits, targets) # Ошибка предсказаний

                    # Обратное распространение для обновления весов
                    self.optimizer.zero_grad()
                    loss.backward()
                    self.optimizer.step()
        
                    total_train_loss += loss.item() # Потеря
                    # Количество правильных предсказаний
                    train_accuracy += (logits.argmax(1) == targets).type(torch.float).sum().item()
        
                    pbar_train.update(1)
                    with torch.no_grad():
                        torch.cuda.empty_cache()

                # Средняя потеря
                avg_train_loss = round(total_train_loss / batch, self.round_loss)
                losses_train_list.append(avg_train_loss)
        
                # Точность
                train_accuracy = round(train_accuracy / len(self.train_dataloader.dataset) * 100, self.round_acc)
                accuracy_train_list.append(train_accuracy)
        
                pbar_train.set_postfix({
                    "Точность": train_accuracy,
                    "Средняя потеря": avg_train_loss
                })
            
            
            # Установка модели в режим предсказаний
            self.model.eval()
        
            # Предсказания на тестовой выборке
            with torch.no_grad():
                with tqdm(total = self.__test_steps, desc = f"Тестирование {epoch}", unit = "batch") as pbar_test:
                    # Проход по всем тестовым пакетам
                    for batch, (batch_X, targets) in enumerate(self.test_dataloader, 1):
                        logits = self.model(batch_X)
                        loss = self.loss_fn(logits, targets) # Ошибка предсказаний
                        
                        total_test_loss += loss.item() # Потеря
                        # Количество правильных предсказаний
                        test_accuracy += (logits.argmax(1) == targets).type(torch.float).sum().item()
        
                        pbar_test.update(1)
                        with torch.no_grad():
                            torch.cuda.empty_cache()

                    # Средняя потеря
                    avg_test_loss = round(total_test_loss / batch, self.round_loss)
                    losses_test_list.append(avg_test_loss)
        
                    # Точность
                    test_accuracy = round(test_accuracy / len(self.test_dataloader.dataset) * 100, self.round_acc)
                    accuracy_test_list.append(test_accuracy)
                    
                    pbar_test.set_postfix({
                        "Точность": test_accuracy,
                        "Средняя потеря": avg_test_loss
                    })
            
            if self._is_best_model(test_accuracy):
                self._save_model(epoch, path_to_model, test_accuracy, avg_test_loss)
                self.__best_test_accuracy = test_accuracy
                self.__no_improvement_count = 0
            else:
                self.__no_improvement_count += 1

            # Добавлениие данных в историю обучения
            new_row = pd.Series([train_accuracy, test_accuracy, avg_train_loss, avg_test_loss], index = self.__history.columns)
            self.__history = pd.concat([self.__history, new_row.to_frame().T], ignore_index = True)

            if self.__no_improvement_count >= self.patience:
                print(f"Ранняя остановка на эпохе {epoch} из-за отсутствия улучшения точности на тестовой выборке")
                break
        # Визуализация графиков потерь и точности
        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.plot(losses_train_list, label = 'Потери на тренировочной выборке')
        plt.plot(losses_test_list, label = 'Потери на тестовой выборке')
        plt.title('Потери во время обучения')
        plt.xlabel('Эпоха')
        plt.ylabel('Потери')
        plt.legend()

        plt.subplot(1, 2, 2)
        plt.plot(accuracy_train_list, label = 'Точность на тренировочной выборке')
        plt.plot(accuracy_test_list, label = 'Точность на тестовой выборке')
        plt.title('Точность во время обучения')
        plt.xlabel('Эпоха')
        plt.ylabel('Точность')
        plt.legend()

        plt.tight_layout()
        plt.show()

    # Получение хэш-значения
    def __hash__(self):
        return id(self)

# %% [markdown]
# ### Метрики

# %%
def evaluate_metrics(model, test_dataloader):
    model.eval()
    y_test = []
    y_predict = []
    with torch.no_grad():
        for batch, (batch_X, targets) in enumerate(test_dataloader, 1):
            y_test.extend(list(map(int, targets)))
            output = model(batch_X)
            _, predictions = torch.max(output, dim=1)
            y_predict.extend(list(map(int, predictions)))
        # Unweighted Average Recall (UAR)
        uar = recall_score(y_test, y_predict, average='macro')
        # Weighted Average Recall (WAR)
        war = recall_score(y_test, y_predict, average='weighted')
        # Macro F1-score (MF1)
        mf1 = f1_score(y_test, y_predict, average='macro')
        # Weighted F1-score (WF1)
        wf1 = f1_score(y_test, y_predict, average='weighted')
    return {'uar': uar, 'war': war, 'mf1': mf1, 'wf1': wf1}

# %%
EPOCHS = 20 # Количество эпох
BATCH_SIZE = 32 # Размер выборки (пакета)
LEARNING_RATE = 1e-4 # Скорость обучения
ROUND_ACC = 2 # Знаков Accuracy после запятой
ROUND_LOSS = 7 # Знаков Loss после запятой
# Проверка наличия GPU
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ROOT_DIR = os.path.join(".")
PATH_TO_MODEL = os.path.join(ROOT_DIR, "models_RESD")

# %%
train_dataloader = DataLoader(dataset=RESDDataset('train'), batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(dataset=RESDDataset('test'), batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ### Transformer

# %%
class TransformerModelWithAttention(nn.Module):
    def __init__(self, num_classes, model_name='jina', pooling=None, num_heads = 8, num_layers = 10, hidden_dim = 1024, dropout = 0.1):
        super(TransformerModelWithAttention, self).__init__()
        embed = Embedding(model_name, pooling)
        self.embedding = embed.get_embeddings
        self.model_name = model_name
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.positional_encoding = nn.Parameter(torch.zeros(1, 500, hidden_dim))
        encoder_layer = nn.TransformerEncoderLayer(d_model = hidden_dim, nhead = num_heads, dim_feedforward = hidden_dim, dropout = dropout)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers = num_layers)
        self.fc_out = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = torch.tensor(self.embedding(x)).to(self.device)
        batch_size, seq_len, _ = x.size()
        x = x + self.positional_encoding[:, :seq_len, :]
        encoder_output = self.transformer_encoder(x).to(self.device)      
        x = encoder_output.mean(dim = 1) # Глобальное усреднение для классификации
        return self.fc_out(x)

# %% [markdown]
# #### Transformer + jina with mean pooling

# %%
model = TransformerModelWithAttention(model_name='jina', pooling='mean', num_classes = 7).to(device)
optimizer = optim.AdamW(params = model.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model, train_dataloader, test_dataloader, DEVICE, EPOCHS, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn)
trainer.train(PATH_TO_MODEL)
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# Эпоха 1: 100%|██████████| 35/35 [00:05<00:00,  6.17batch/s, Точность=15.2, Средняя потеря=2.14]
# Тестирование 1: 100%|██████████| 9/9 [00:01<00:00,  6.51batch/s, Точность=13.2, Средняя потеря=2.02]
# Эпоха 2: 100%|██████████| 35/35 [00:05<00:00,  6.40batch/s, Точность=13.3, Средняя потеря=2.05]
# Тестирование 2: 100%|██████████| 9/9 [00:01<00:00,  6.56batch/s, Точность=13.2, Средняя потеря=1.98]
# Эпоха 3: 100%|██████████| 35/35 [00:05<00:00,  6.31batch/s, Точность=15.6, Средняя потеря=2]
# Тестирование 3: 100%|██████████| 9/9 [00:01<00:00,  6.61batch/s, Точность=16.1, Средняя потеря=1.97]
# Эпоха 4: 100%|██████████| 35/35 [00:06<00:00,  5.18batch/s, Точность=15.5, Средняя потеря=1.97]
# Тестирование 4: 100%|██████████| 9/9 [00:01<00:00,  6.61batch/s, Точность=15.7, Средняя потеря=1.98]
# Эпоха 5: 100%|██████████| 35/35 [00:05<00:00,  6.30batch/s, Точность=14.9, Средняя потеря=2]
# Тестирование 5: 100%|██████████| 9/9 [00:01<00:00,  6.62batch/s, Точность=15.7, Средняя потеря=2.03]
# Эпоха 6: 100%|██████████| 35/35 [00:05<00:00,  6.28batch/s, Точность=15, Средняя потеря=2.01]
# Тестирование 6: 100%|██████████| 9/9 [00:01<00:00,  6.63batch/s, Точность=16.1, Средняя потеря=1.96]
# Эпоха 7: 100%|██████████| 35/35 [00:05<00:00,  6.38batch/s, Точность=16.7, Средняя потеря=1.99]
# Тестирование 7: 100%|██████████| 9/9 [00:01<00:00,  6.63batch/s, Точность=16.1, Средняя потеря=1.99]
# Эпоха 8: 100%|██████████| 35/35 [00:05<00:00,  6.23batch/s, Точность=15.1, Средняя потеря=2]
# Тестирование 8: 100%|██████████| 9/9 [00:01<00:00,  6.64batch/s, Точность=15.7, Средняя потеря=2]
# Ранняя остановка на эпохе 8 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_transformer_best = TransformerModelWithAttention(model_name='jina', pooling='mean', num_classes = 7).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "TransformerModelWithAttention_jina_3_16.07_checkpoint.pth"))
model_transformer_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# <All keys matched successfully>

# %%
evaluate_metrics(model_transformer_best, test_dataloader)
# Out:
# {'uar': 0.14285714285714285,
#  'war': 0.16071428571428573,
#  'mf1': 0.039560439560439566,
#  'wf1': 0.04450549450549451}

# %% [markdown]
# #### Transformer + jina

# %%
model = TransformerModelWithAttention(num_classes = 7, model_name='jina').to(device)
optimizer = optim.AdamW(params = model.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# Эпоха 1: 100%|██████████| 35/35 [00:12<00:00,  2.70batch/s, Точность=14.1, Средняя потеря=2.17]
# Тестирование 1: 100%|██████████| 9/9 [00:01<00:00,  4.54batch/s, Точность=13.6, Средняя потеря=2.01]
# Эпоха 2: 100%|██████████| 35/35 [00:11<00:00,  3.02batch/s, Точность=13.7, Средняя потеря=2]
# Тестирование 2: 100%|██████████| 9/9 [00:01<00:00,  4.61batch/s, Точность=15.4, Средняя потеря=1.97]
# Эпоха 3: 100%|██████████| 35/35 [00:10<00:00,  3.40batch/s, Точность=15, Средняя потеря=1.97]
# Тестирование 3: 100%|██████████| 9/9 [00:01<00:00,  4.82batch/s, Точность=14.3, Средняя потеря=1.99]
# Эпоха 4: 100%|██████████| 35/35 [00:10<00:00,  3.42batch/s, Точность=15.1, Средняя потеря=2]
# Тестирование 4: 100%|██████████| 9/9 [00:01<00:00,  4.88batch/s, Точность=15, Средняя потеря=2]
# Эпоха 5: 100%|██████████| 35/35 [00:10<00:00,  3.43batch/s, Точность=17.6, Средняя потеря=1.96]
# Тестирование 5: 100%|██████████| 9/9 [00:01<00:00,  4.65batch/s, Точность=16.8, Средняя потеря=1.97]
# Эпоха 6: 100%|██████████| 35/35 [00:10<00:00,  3.25batch/s, Точность=14.1, Средняя потеря=1.96]
# Тестирование 6: 100%|██████████| 9/9 [00:01<00:00,  4.84batch/s, Точность=15.4, Средняя потеря=2.01]
# Эпоха 7: 100%|██████████| 35/35 [00:10<00:00,  3.38batch/s, Точность=12.6, Средняя потеря=1.97]
# Тестирование 7: 100%|██████████| 9/9 [00:01<00:00,  4.79batch/s, Точность=15.7, Средняя потеря=2]
# Эпоха 8: 100%|██████████| 35/35 [00:10<00:00,  3.36batch/s, Точность=15.4, Средняя потеря=1.97]
# Тестирование 8: 100%|██████████| 9/9 [00:01<00:00,  4.85batch/s, Точность=18.6, Средняя потеря=1.95]
# Эпоха 9: 100%|██████████| 35/35 [00:10<00:00,  3.35batch/s, Точность=14.2, Средняя потеря=1.97]
# Тестирование 9: 100%|██████████| 9/9 [00:01<00:00,  4.72batch/s, Точность=13.9, Средняя потеря=1.96]
# Эпоха 10: 100%|██████████| 35/35 [00:10<00:00,  3.39batch/s, Точность=15.9, Средняя потеря=1.96]
# Тестирование 10: 100%|██████████| 9/9 [00:01<00:00,  4.85batch/s, Точность=13.9, Средняя потеря=1.95]
# Эпоха 11: 100%|██████████| 35/35 [00:09<00:00,  3.50batch/s, Точность=14.7, Средняя потеря=1.96]
# Тестирование 11: 100%|██████████| 9/9 [00:01<00:00,  4.91batch/s, Точность=15.4, Средняя потеря=1.96]
# Эпоха 12: 100%|██████████| 35/35 [00:09<00:00,  3.52batch/s, Точность=15.8, Средняя потеря=1.95]
# Тестирование 12: 100%|██████████| 9/9 [00:01<00:00,  4.86batch/s, Точность=15.7, Средняя потеря=2]
# Эпоха 13: 100%|██████████| 35/35 [00:10<00:00,  3.42batch/s, Точность=15.2, Средняя потеря=1.97]
# Тестирование 13: 100%|██████████| 9/9 [00:01<00:00,  4.78batch/s, Точность=15.4, Средняя потеря=1.97]
# Эпоха 14: 100%|██████████| 35/35 [00:10<00:00,  3.42batch/s, Точность=15.9, Средняя потеря=1.97]
# Тестирование 14: 100%|██████████| 9/9 [00:01<00:00,  4.75batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 15: 100%|██████████| 35/35 [00:10<00:00,  3.40batch/s, Точность=16.4, Средняя потеря=1.96]
# Тестирование 15: 100%|██████████| 9/9 [00:01<00:00,  4.75batch/s, Точность=16.1, Средняя потеря=1.99]
# Эпоха 16: 100%|██████████| 35/35 [00:10<00:00,  3.40batch/s, Точность=12.7, Средняя потеря=1.96]
# Тестирование 16: 100%|██████████| 9/9 [00:01<00:00,  4.75batch/s, Точность=15, Средняя потеря=1.96]
# Эпоха 17: 100%|██████████| 35/35 [00:10<00:00,  3.39batch/s, Точность=16.6, Средняя потеря=1.96]
# Тестирование 17: 100%|██████████| 9/9 [00:01<00:00,  4.81batch/s, Точность=13.9, Средняя потеря=1.96]
# Эпоха 18: 100%|██████████| 35/35 [00:10<00:00,  3.37batch/s, Точность=15.2, Средняя потеря=1.96]
# Тестирование 18: 100%|██████████| 9/9 [00:01<00:00,  4.75batch/s, Точность=12.9, Средняя потеря=1.96]
# Ранняя остановка на эпохе 18 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_transformer_best = TransformerModelWithAttention(num_classes = 7, model_name='jina').to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "TransformerModelWithAttention_jina_8_18.57_checkpoint.pth"))
model_transformer_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# <All keys matched successfully>

# %%
evaluate_metrics(model_transformer_best, test_dataloader)
# Out:
# {'uar': 0.1688311688311688,
#  'war': 0.18571428571428572,
#  'mf1': 0.08249194414607948,
#  'wf1': 0.09074113856068743}

# %% [markdown]
# #### Transformer + xlm-roberta-base with mean pooling

# %%
model_transformer = TransformerModelWithAttention(num_classes = 7, model_name='xlm-roberta-base', pooling='mean', hidden_dim=768, num_heads=8).to(device)
optimizer = optim.AdamW(params = model_transformer.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model_transformer, train_dataloader, test_dataloader, DEVICE, EPOCHS, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:22<00:00,  1.52batch/s, Точность=14, Средняя потеря=2.07]
# Тестирование 1: 100%|██████████| 9/9 [00:06<00:00,  1.46batch/s, Точность=14.3, Средняя потеря=1.96]
# Эпоха 2: 100%|██████████| 35/35 [00:22<00:00,  1.58batch/s, Точность=16, Средняя потеря=1.98]
# Тестирование 2: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=14.3, Средняя потеря=2.01]
# Эпоха 3: 100%|██████████| 35/35 [00:22<00:00,  1.57batch/s, Точность=13.3, Средняя потеря=1.99]
# Тестирование 3: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=15.7, Средняя потеря=1.98]
# Эпоха 4: 100%|██████████| 35/35 [00:22<00:00,  1.58batch/s, Точность=14.2, Средняя потеря=1.98]
# Тестирование 4: 100%|██████████| 9/9 [00:05<00:00,  1.62batch/s, Точность=14.3, Средняя потеря=1.97]
# Эпоха 5: 100%|██████████| 35/35 [00:22<00:00,  1.57batch/s, Точность=14.9, Средняя потеря=1.99]
# Тестирование 5: 100%|██████████| 9/9 [00:05<00:00,  1.62batch/s, Точность=13.6, Средняя потеря=1.98]
# Эпоха 6: 100%|██████████| 35/35 [00:22<00:00,  1.52batch/s, Точность=15.2, Средняя потеря=1.99]
# Тестирование 6: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 7: 100%|██████████| 35/35 [00:22<00:00,  1.56batch/s, Точность=14.2, Средняя потеря=1.99]
# Тестирование 7: 100%|██████████| 9/9 [00:05<00:00,  1.61batch/s, Точность=16.1, Средняя потеря=2]
# Эпоха 8: 100%|██████████| 35/35 [00:23<00:00,  1.52batch/s, Точность=13.3, Средняя потеря=1.98]
# Тестирование 8: 100%|██████████| 9/9 [00:05<00:00,  1.58batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 9: 100%|██████████| 35/35 [00:22<00:00,  1.55batch/s, Точность=14.2, Средняя потеря=1.97]
# Тестирование 9: 100%|██████████| 9/9 [00:05<00:00,  1.61batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 10: 100%|██████████| 35/35 [00:23<00:00,  1.51batch/s, Точность=15.7, Средняя потеря=1.98]
# Тестирование 10: 100%|██████████| 9/9 [00:05<00:00,  1.60batch/s, Точность=15.7, Средняя потеря=1.96]
# Эпоха 11: 100%|██████████| 35/35 [00:22<00:00,  1.54batch/s, Точность=14.4, Средняя потеря=1.99]
# Тестирование 11: 100%|██████████| 9/9 [00:05<00:00,  1.60batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 12: 100%|██████████| 35/35 [00:23<00:00,  1.50batch/s, Точность=14.9, Средняя потеря=1.96]
# Тестирование 12: 100%|██████████| 9/9 [00:05<00:00,  1.58batch/s, Точность=15.7, Средняя потеря=1.95]
# Ранняя остановка на эпохе 12 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_transformer_best = TransformerModelWithAttention(num_classes = 7, model_name='xlm-roberta-base', pooling='mean', hidden_dim=768, num_heads=8).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "TransformerModelWithAttention_xlm-roberta-base_7_16.07_checkpoint.pth"))
model_transformer_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_transformer_best, test_dataloader)
# Out:
# {'uar': 0.14285714285714285,
#  'war': 0.16071428571428573,
#  'mf1': 0.039560439560439566,
#  'wf1': 0.04450549450549451,
#  'accuracy': 0.16071428571428573}

# %% [markdown]
# #### Transformer + xlm-roberta-base

# %%
model_transformer = TransformerModelWithAttention(num_classes = 7, model_name='xlm-roberta-base', pooling=None, hidden_dim=768, num_heads=8).to(device)
optimizer = optim.AdamW(params = model_transformer.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model_transformer, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:38<00:00,  1.09s/batch, Точность=15.1, Средняя потеря=2.04]
# Тестирование 1: 100%|██████████| 9/9 [00:08<00:00,  1.12batch/s, Точность=16.1, Средняя потеря=2.03]
# Эпоха 2: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=14.1, Средняя потеря=1.98]
# Тестирование 2: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=16.1, Средняя потеря=1.97]
# Эпоха 3: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=11.8, Средняя потеря=1.99]
# Тестирование 3: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=16.1, Средняя потеря=1.96]
# Эпоха 4: 100%|██████████| 35/35 [00:33<00:00,  1.04batch/s, Точность=14.2, Средняя потеря=1.97]
# Тестирование 4: 100%|██████████| 9/9 [00:08<00:00,  1.04batch/s, Точность=12.1, Средняя потеря=1.98]
# Эпоха 5: 100%|██████████| 35/35 [00:33<00:00,  1.04batch/s, Точность=17.7, Средняя потеря=1.96]
# Тестирование 5: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=17.5, Средняя потеря=2]
# Эпоха 6: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=14.1, Средняя потеря=1.97]
# Тестирование 6: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=15.7, Средняя потеря=1.98]
# Эпоха 7: 100%|██████████| 35/35 [00:33<00:00,  1.03batch/s, Точность=15.9, Средняя потеря=1.96]
# Тестирование 7: 100%|██████████| 9/9 [00:08<00:00,  1.05batch/s, Точность=15.7, Средняя потеря=1.96]
# Эпоха 8: 100%|██████████| 35/35 [00:33<00:00,  1.04batch/s, Точность=16.1, Средняя потеря=1.95]
# Тестирование 8: 100%|██████████| 9/9 [00:07<00:00,  1.14batch/s, Точность=15.7, Средняя потеря=1.96]
# Эпоха 9: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=15.5, Средняя потеря=1.96]
# Тестирование 9: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=13.2, Средняя потеря=1.97]
# Эпоха 10: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=14.2, Средняя потеря=1.96]
# Тестирование 10: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 11: 100%|██████████| 35/35 [00:33<00:00,  1.04batch/s, Точность=16.3, Средняя потеря=1.95]
# Тестирование 11: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=15.7, Средняя потеря=1.98]
# Эпоха 12: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=17.2, Средняя потеря=1.96]
# Тестирование 12: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=16.4, Средняя потеря=1.95]
# Эпоха 13: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=12.6, Средняя потеря=1.96]
# Тестирование 13: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 14: 100%|██████████| 35/35 [00:33<00:00,  1.04batch/s, Точность=13.7, Средняя потеря=1.96]
# Тестирование 14: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=17.9, Средняя потеря=1.94]
# Эпоха 15: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=13.8, Средняя потеря=1.95]
# Тестирование 15: 100%|██████████| 9/9 [00:07<00:00,  1.14batch/s, Точность=15.7, Средняя потеря=1.96]
# Эпоха 16: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=15.1, Средняя потеря=1.95]
# Тестирование 16: 100%|██████████| 9/9 [00:07<00:00,  1.14batch/s, Точность=15.7, Средняя потеря=1.97]
# Эпоха 17: 100%|██████████| 35/35 [00:33<00:00,  1.04batch/s, Точность=14.7, Средняя потеря=1.95]
# Тестирование 17: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 18: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=14.7, Средняя потеря=1.95]
# Тестирование 18: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=15.7, Средняя потеря=1.96]
# Эпоха 19: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 19: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=12.9, Средняя потеря=1.96]
# Эпоха 20: 100%|██████████| 35/35 [00:33<00:00,  1.04batch/s, Точность=15.1, Средняя потеря=1.95]
# Тестирование 20: 100%|██████████| 9/9 [00:07<00:00,  1.14batch/s, Точность=14.3, Средняя потеря=1.96]
# Эпоха 21: 100%|██████████| 35/35 [00:34<00:00,  1.02batch/s, Точность=15.9, Средняя потеря=1.96]
# Тестирование 21: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=12.5, Средняя потеря=1.96]
# Эпоха 22: 100%|██████████| 35/35 [00:34<00:00,  1.03batch/s, Точность=13.7, Средняя потеря=1.95]
# Тестирование 22: 100%|██████████| 9/9 [00:07<00:00,  1.14batch/s, Точность=15.7, Средняя потеря=1.99]
# Эпоха 23: 100%|██████████| 35/35 [00:33<00:00,  1.05batch/s, Точность=15.1, Средняя потеря=1.96]
# Тестирование 23: 100%|██████████| 9/9 [00:07<00:00,  1.14batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 24: 100%|██████████| 35/35 [00:33<00:00,  1.05batch/s, Точность=15.1, Средняя потеря=1.95]
# Тестирование 24: 100%|██████████| 9/9 [00:07<00:00,  1.13batch/s, Точность=15.7, Средняя потеря=1.95]
# Ранняя остановка на эпохе 24 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_transformer_best = TransformerModelWithAttention(num_classes = 7, model_name='xlm-roberta-base', pooling=None, hidden_dim=768, num_heads=8).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "TransformerModelWithAttention_xlm-roberta-base_emb_14_17.86_checkpoint.pth"))
model_transformer_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_transformer_best, test_dataloader)
# Out:
# {'uar': 0.16233766233766236,
#  'war': 0.17857142857142858,
#  'mf1': 0.07683494450411743,
#  'wf1': 0.08451843895452918,
#  'accuracy': 0.17857142857142858}

# %% [markdown]
# #### Transformer + canine-c with mean pooling

# %%
model_transformer = TransformerModelWithAttention(num_classes = 7, model_name='canine-c', pooling='mean', hidden_dim=768, num_heads=8).to(device)
optimizer = optim.AdamW(params = model_transformer.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model_transformer, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:04<00:00,  7.45batch/s, Точность=14.2, Средняя потеря=2.08]
# Тестирование 1: 100%|██████████| 9/9 [00:00<00:00, 12.34batch/s, Точность=16.1, Средняя потеря=2.02]
# Эпоха 2: 100%|██████████| 35/35 [00:03<00:00, 10.41batch/s, Точность=14.1, Средняя потеря=2.02]
# Тестирование 2: 100%|██████████| 9/9 [00:00<00:00, 12.60batch/s, Точность=13.2, Средняя потеря=1.96]
# Эпоха 3: 100%|██████████| 35/35 [00:03<00:00,  9.59batch/s, Точность=13.1, Средняя потеря=1.98]
# Тестирование 3: 100%|██████████| 9/9 [00:00<00:00, 12.56batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 4: 100%|██████████| 35/35 [00:03<00:00, 10.85batch/s, Точность=13.9, Средняя потеря=1.98]
# Тестирование 4: 100%|██████████| 9/9 [00:00<00:00, 11.65batch/s, Точность=13.2, Средняя потеря=1.98]
# Эпоха 5: 100%|██████████| 35/35 [00:03<00:00, 10.67batch/s, Точность=14.1, Средняя потеря=1.98]
# Тестирование 5: 100%|██████████| 9/9 [00:00<00:00, 12.72batch/s, Точность=14.3, Средняя потеря=1.96]
# Эпоха 6: 100%|██████████| 35/35 [00:03<00:00, 10.63batch/s, Точность=12.9, Средняя потеря=2.01]
# Тестирование 6: 100%|██████████| 9/9 [00:00<00:00, 12.94batch/s, Точность=15.7, Средняя потеря=1.99]
# Эпоха 7: 100%|██████████| 35/35 [00:03<00:00, 10.61batch/s, Точность=12.8, Средняя потеря=1.99]
# Тестирование 7: 100%|██████████| 9/9 [00:00<00:00, 12.48batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 8: 100%|██████████| 35/35 [00:03<00:00, 10.44batch/s, Точность=15.9, Средняя потеря=1.97]
# Тестирование 8: 100%|██████████| 9/9 [00:00<00:00, 13.10batch/s, Точность=14.3, Средняя потеря=1.98]
# Эпоха 9: 100%|██████████| 35/35 [00:03<00:00, 10.81batch/s, Точность=15.5, Средняя потеря=1.97]
# Тестирование 9: 100%|██████████| 9/9 [00:00<00:00, 12.75batch/s, Точность=15.7, Средняя потеря=1.96]
# Эпоха 10: 100%|██████████| 35/35 [00:03<00:00, 10.44batch/s, Точность=15.4, Средняя потеря=1.97]
# Тестирование 10: 100%|██████████| 9/9 [00:00<00:00, 12.52batch/s, Точность=14.3, Средняя потеря=2]
# Эпоха 11: 100%|██████████| 35/35 [00:03<00:00, 10.77batch/s, Точность=16.6, Средняя потеря=1.97]
# Тестирование 11: 100%|██████████| 9/9 [00:00<00:00, 11.89batch/s, Точность=16.1, Средняя потеря=1.95]
# Ранняя остановка на эпохе 11 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_transformer = TransformerModelWithAttention(num_classes = 7, model_name='canine-c', pooling='mean', hidden_dim=768, num_heads=8).to(device)
optimizer = optim.AdamW(params = model_transformer.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model_transformer, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:02<00:00, 11.67batch/s, Точность=13.8, Средняя потеря=2.1]
# Тестирование 1: 100%|██████████| 9/9 [00:00<00:00, 14.15batch/s, Точность=13.6, Средняя потеря=2.01]
# Эпоха 2: 100%|██████████| 35/35 [00:02<00:00, 11.73batch/s, Точность=14, Средняя потеря=2]
# Тестирование 2: 100%|██████████| 9/9 [00:00<00:00, 13.92batch/s, Точность=14.3, Средняя потеря=1.99]
# Эпоха 3: 100%|██████████| 35/35 [00:02<00:00, 11.74batch/s, Точность=12.3, Средняя потеря=1.99]
# Тестирование 3: 100%|██████████| 9/9 [00:00<00:00, 13.76batch/s, Точность=15.7, Средняя потеря=1.99]
# Эпоха 4: 100%|██████████| 35/35 [00:02<00:00, 11.97batch/s, Точность=14.1, Средняя потеря=1.98]
# Тестирование 4: 100%|██████████| 9/9 [00:00<00:00, 14.10batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 5: 100%|██████████| 35/35 [00:02<00:00, 11.73batch/s, Точность=15, Средняя потеря=1.98]
# Тестирование 5: 100%|██████████| 9/9 [00:00<00:00, 13.81batch/s, Точность=14.3, Средняя потеря=1.99]
# Эпоха 6: 100%|██████████| 35/35 [00:02<00:00, 11.85batch/s, Точность=15.6, Средняя потеря=1.99]
# Тестирование 6: 100%|██████████| 9/9 [00:00<00:00, 13.84batch/s, Точность=16.1, Средняя потеря=1.99]
# Эпоха 7: 100%|██████████| 35/35 [00:02<00:00, 11.79batch/s, Точность=13.3, Средняя потеря=1.99]
# Тестирование 7: 100%|██████████| 9/9 [00:00<00:00, 13.91batch/s, Точность=14.3, Средняя потеря=1.97]
# Эпоха 8: 100%|██████████| 35/35 [00:02<00:00, 11.68batch/s, Точность=15.1, Средняя потеря=1.99]
# Тестирование 8: 100%|██████████| 9/9 [00:00<00:00, 14.05batch/s, Точность=13.6, Средняя потеря=1.95]
# Эпоха 9: 100%|██████████| 35/35 [00:02<00:00, 11.82batch/s, Точность=15.4, Средняя потеря=1.97]
# Тестирование 9: 100%|██████████| 9/9 [00:00<00:00, 13.82batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 10: 100%|██████████| 35/35 [00:02<00:00, 11.69batch/s, Точность=14.8, Средняя потеря=1.97]
# Тестирование 10: 100%|██████████| 9/9 [00:00<00:00, 14.00batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 11: 100%|██████████| 35/35 [00:02<00:00, 11.87batch/s, Точность=15.1, Средняя потеря=1.97]
# Тестирование 11: 100%|██████████| 9/9 [00:00<00:00, 13.68batch/s, Точность=15.7, Средняя потеря=1.97]
# Эпоха 12: 100%|██████████| 35/35 [00:02<00:00, 12.40batch/s, Точность=15.1, Средняя потеря=1.98]
# Тестирование 12: 100%|██████████| 9/9 [00:00<00:00, 14.33batch/s, Точность=15.7, Средняя потеря=1.96]
# Эпоха 13: 100%|██████████| 35/35 [00:02<00:00, 12.24batch/s, Точность=15.8, Средняя потеря=1.97]
# Тестирование 13: 100%|██████████| 9/9 [00:00<00:00, 13.96batch/s, Точность=16.1, Средняя потеря=1.96]
# Эпоха 14: 100%|██████████| 35/35 [00:03<00:00, 11.51batch/s, Точность=14.1, Средняя потеря=1.97]
# Тестирование 14: 100%|██████████| 9/9 [00:00<00:00, 13.61batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 15: 100%|██████████| 35/35 [00:03<00:00, 10.48batch/s, Точность=14.2, Средняя потеря=1.96]
# Тестирование 15: 100%|██████████| 9/9 [00:00<00:00, 14.38batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 16: 100%|██████████| 35/35 [00:03<00:00, 10.96batch/s, Точность=16.3, Средняя потеря=1.96]
# Тестирование 16: 100%|██████████| 9/9 [00:00<00:00, 14.32batch/s, Точность=15.7, Средняя потеря=1.97]
# Ранняя остановка на эпохе 16 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_transformer_best = TransformerModelWithAttention(num_classes = 7, model_name='canine-c', pooling='mean', hidden_dim=768, num_heads=8).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "TransformerModelWithAttention_canine-c_6_16.07_checkpoint.pth"))
model_transformer_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_transformer_best, test_dataloader)
# Out:
# {'uar': 0.14285714285714285,
#  'war': 0.16071428571428573,
#  'mf1': 0.039560439560439566,
#  'wf1': 0.04450549450549451}

# %% [markdown]
# #### Transformer + canine-c

# %%
model_transformer = TransformerModelWithAttention(num_classes = 7, model_name='canine-c', pooling=None, hidden_dim=768, num_heads=8).to(device)
optimizer = optim.AdamW(params = model_transformer.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model_transformer, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:41<00:00,  1.19s/batch, Точность=16.3, Средняя потеря=2.11]
# Тестирование 1: 100%|██████████| 9/9 [00:08<00:00,  1.01batch/s, Точность=13.9, Средняя потеря=1.96]
# Эпоха 2: 100%|██████████| 35/35 [00:42<00:00,  1.21s/batch, Точность=15.3, Средняя потеря=1.98]
# Тестирование 2: 100%|██████████| 9/9 [00:08<00:00,  1.00batch/s, Точность=17.5, Средняя потеря=1.96]
# Эпоха 3: 100%|██████████| 35/35 [00:41<00:00,  1.19s/batch, Точность=15.2, Средняя потеря=1.98]
# Тестирование 3: 100%|██████████| 9/9 [00:08<00:00,  1.02batch/s, Точность=15, Средняя потеря=1.98]
# Эпоха 4: 100%|██████████| 35/35 [00:41<00:00,  1.19s/batch, Точность=15, Средняя потеря=1.97]
# Тестирование 4: 100%|██████████| 9/9 [00:08<00:00,  1.01batch/s, Точность=16.1, Средняя потеря=1.96]
# Эпоха 5: 100%|██████████| 35/35 [00:41<00:00,  1.20s/batch, Точность=16.3, Средняя потеря=1.96]
# Тестирование 5: 100%|██████████| 9/9 [00:08<00:00,  1.01batch/s, Точность=17.1, Средняя потеря=1.95]
# Эпоха 6: 100%|██████████| 35/35 [00:41<00:00,  1.19s/batch, Точность=15.4, Средняя потеря=1.97]
# Тестирование 6: 100%|██████████| 9/9 [00:08<00:00,  1.02batch/s, Точность=15, Средняя потеря=1.98]
# Эпоха 7: 100%|██████████| 35/35 [00:41<00:00,  1.20s/batch, Точность=15.3, Средняя потеря=1.96]
# Тестирование 7: 100%|██████████| 9/9 [00:08<00:00,  1.01batch/s, Точность=15.7, Средняя потеря=1.97]
# Эпоха 8: 100%|██████████| 35/35 [00:41<00:00,  1.19s/batch, Точность=14.4, Средняя потеря=1.96]
# Тестирование 8: 100%|██████████| 9/9 [00:08<00:00,  1.01batch/s, Точность=13.9, Средняя потеря=1.98]
# Эпоха 9: 100%|██████████| 35/35 [00:41<00:00,  1.19s/batch, Точность=10.7, Средняя потеря=1.97]
# Тестирование 9: 100%|██████████| 9/9 [00:08<00:00,  1.01batch/s, Точность=17.1, Средняя потеря=1.95]
# Эпоха 10: 100%|██████████| 35/35 [00:41<00:00,  1.19s/batch, Точность=14, Средняя потеря=1.96]
# Тестирование 10: 100%|██████████| 9/9 [00:08<00:00,  1.02batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 11: 100%|██████████| 35/35 [00:41<00:00,  1.18s/batch, Точность=14.1, Средняя потеря=1.96]
# Тестирование 11: 100%|██████████| 9/9 [00:08<00:00,  1.01batch/s, Точность=15.7, Средняя потеря=1.98]
# Эпоха 12: 100%|██████████| 35/35 [00:41<00:00,  1.19s/batch, Точность=15.7, Средняя потеря=1.97]
# Тестирование 12: 100%|██████████| 9/9 [00:08<00:00,  1.01batch/s, Точность=12.9, Средняя потеря=1.96]
# Ранняя остановка на эпохе 12 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_transformer_best = TransformerModelWithAttention(num_classes = 7, model_name='canine-c', pooling=None, hidden_dim=768, num_heads=8).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "TransformerModelWithAttention_canine-c_emb_2_17.5_checkpoint.pth"))
model_transformer_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_transformer_best, test_dataloader)
# Out:
# {'uar': 0.1623376623376623,
#  'war': 0.175,
#  'mf1': 0.07032967032967033,
#  'wf1': 0.07461538461538461,
#  'accuracy': 0.175}

# %% [markdown]
# ### Mamba

# %%
class PScan(Function):
    @staticmethod
    def forward(ctx, A_inp, X_inp):
        A, X = A_inp.clone(), X_inp.clone()
        A, X = rearrange(A, "l b d s -> b d l s"), rearrange(X, "l b d s -> b d l s")
        PScan._forward(A, X)
        ctx.save_for_backward(A.clone(), X)
        return rearrange(X, "b d l s -> b l d s")

    @staticmethod
    def backward(ctx, grad_inp: Tensor) -> Tuple[Tensor, Tensor]:
        A, X = ctx.saved_tensors
        A = torch.cat((A[:, :, :1], A[:, :, 1:].flip(2)), dim = 2)
        grad_out = rearrange(grad_inp, "b l d s -> b d l s")
        grad_out = grad_out.flip(2)
        PScan._forward(A, grad_out)
        grad_out = grad_out.flip(2)
        Q = torch.zeros_like(X)
        Q[:, :, 1:].add_(X[:, :, :-1] * grad_out[:, :, 1:])
        return rearrange(Q, "b d l s -> b l d s"), rearrange(grad_out, "b d l s -> b l d s")

    @staticmethod
    def _forward(A: Tensor, X: Tensor) -> None:
        b, d, l, s = A.shape
        num_steps = int(math.log2(l))
        Av, Xv = A, X
        for _ in range(num_steps):
            T = Xv.size(2)
            Av, Xv = Av[:, :, :T].reshape(b, d, T // 2, 2, -1), Xv[:, :, :T].reshape(b, d, T // 2, 2, -1)
            Xv[:, :, :, 1].add_(Av[:, :, :, 1].mul(Xv[:, :, :, 0]))
            Av[:, :, :, 1].mul_(Av[:, :, :, 0])
            Av, Xv = Av[:, :, :, 1], Xv[:, :, :, 1]
        for k in range(num_steps - 1, -1, -1):
            Av, Xv = A[:, :, 2**k - 1 : l : 2**k], X[:, :, 2**k - 1 : l : 2**k]
            T = 2 * (Xv.size(2) // 2)
            if T < Xv.size(2):
                Xv[:, :, -1].add_(Av[:, :, -1].mul(Xv[:, :, -2]))
                Av[:, :, -1].mul_(Av[:, :, -2])
            Av, Xv = Av[:, :, :T].reshape(b, d, T // 2, 2, -1), Xv[:, :, :T].reshape(b, d, T // 2, 2, -1)
            Xv[:, :, 1:, 0].add_(Av[:, :, 1:, 0].mul(Xv[:, :, :-1, 1]))
            Av[:, :, 1:, 0].mul_(Av[:, :, :-1, 1])

pscan: Callable[[Tensor, Tensor], Tensor] = PScan.apply

class RMSNorm(nn.Module):
    def __init__(self, d_model: int, eps: float = 1e-8) -> None:
        super().__init__()
        self.eps = eps
        self.weight = nn.Parameter(torch.ones(d_model))

    def forward(self, x: Tensor) -> Tensor:        
        return x * torch.rsqrt(x.pow(2).mean(-1, keepdim = True) + self.eps) * self.weight

class MambaBlock(nn.Module):
    def __init__(self, d_input, d_model):
        super(MambaBlock, self).__init__()
        self.in_proj = nn.Linear(d_input, d_model)
        self.s_B = nn.Linear(d_model, d_model)
        self.s_C = nn.Linear(d_model, d_model)
        self.out_proj = nn.Linear(d_model, d_input)

    def forward(self, x):
        x = x.to(device)
        x = self.in_proj(x)
        B, C = self.s_B(x), self.s_C(x)
        res = self.out_proj(x + B + C)
        return res

class Mamba(nn.Module):
    def __init__(self, num_layers, d_input, d_model, num_classes, model_name='jina', pooling=None):
        super(Mamba, self).__init__()
        embed = Embedding(model_name, pooling)
        self.embedding = embed.get_embeddings
        self.layers = nn.ModuleList([MambaBlock(d_input, d_model) for _ in range(num_layers)])
        self.fc_out = nn.Linear(d_input, num_classes)
        self.model_name = model_name

    def forward(self, seq):
        seq = torch.tensor(self.embedding(seq)).to(device)
        for mamba in self.layers:
            seq = mamba(seq)
        return self.fc_out(seq.mean(dim = 1))
    def predict(self, x):
        transform_idx_to_labels = ['anger', 'disgust', 'fear', 'sadness', 'neutral', 'happiness', 'enthusiasm']
        with torch.no_grad():
            output = self.forward(x)
            _, predictions = torch.max(output, dim=1)
            result = [transform_idx_to_labels[i] for i in (map(int, predictions))]
        return result

# %% [markdown]
# #### Mamba + jina with mean pooling

# %%
model_mamba = Mamba(num_layers = 6, d_input = 1024, d_model = 256, num_classes=7, model_name='jina', pooling='mean').to(device)
optimizer = optim.AdamW(params = model_mamba.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model_mamba, train_dataloader, test_dataloader, DEVICE, EPOCHS, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn)
trainer.train(PATH_TO_MODEL)
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# Эпоха 1: 100%|██████████| 35/35 [01:07<00:00,  1.93s/batch, Точность=13.3, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:17<00:00,  1.90s/batch, Точность=16.1, Средняя потеря=1.94]
# Эпоха 2: 100%|██████████| 35/35 [01:07<00:00,  1.92s/batch, Точность=17.5, Средняя потеря=1.94]
# Тестирование 2: 100%|██████████| 9/9 [00:17<00:00,  1.98s/batch, Точность=22.9, Средняя потеря=1.86]
# Эпоха 3: 100%|██████████| 35/35 [01:06<00:00,  1.91s/batch, Точность=24.1, Средняя потеря=1.87]
# Тестирование 3: 100%|██████████| 9/9 [00:17<00:00,  1.91s/batch, Точность=22.5, Средняя потеря=1.82]
# Эпоха 4: 100%|██████████| 35/35 [01:06<00:00,  1.91s/batch, Точность=24.7, Средняя потеря=1.83]
# Тестирование 4: 100%|██████████| 9/9 [00:17<00:00,  1.90s/batch, Точность=23.6, Средняя потеря=1.82]
# Эпоха 5: 100%|██████████| 35/35 [01:05<00:00,  1.87s/batch, Точность=26.3, Средняя потеря=1.82]
# Тестирование 5: 100%|██████████| 9/9 [00:16<00:00,  1.86s/batch, Точность=21.8, Средняя потеря=1.81]
# Эпоха 6: 100%|██████████| 35/35 [01:06<00:00,  1.91s/batch, Точность=27.1, Средняя потеря=1.75]
# Тестирование 6: 100%|██████████| 9/9 [00:16<00:00,  1.87s/batch, Точность=21.4, Средняя потеря=1.84]
# Эпоха 7: 100%|██████████| 35/35 [01:06<00:00,  1.90s/batch, Точность=27.1, Средняя потеря=1.75]
# Тестирование 7: 100%|██████████| 9/9 [00:17<00:00,  1.96s/batch, Точность=21.8, Средняя потеря=1.85]
# Эпоха 8: 100%|██████████| 35/35 [01:06<00:00,  1.90s/batch, Точность=29.4, Средняя потеря=1.73]
# Тестирование 8: 100%|██████████| 9/9 [00:16<00:00,  1.88s/batch, Точность=23.2, Средняя потеря=1.83]
# Эпоха 9: 100%|██████████| 35/35 [01:06<00:00,  1.90s/batch, Точность=28.1, Средняя потеря=1.72]
# Тестирование 9: 100%|██████████| 9/9 [00:16<00:00,  1.88s/batch, Точность=26.8, Средняя потеря=1.86]
# Эпоха 10: 100%|██████████| 35/35 [01:06<00:00,  1.89s/batch, Точность=30.5, Средняя потеря=1.7]
# Тестирование 10: 100%|██████████| 9/9 [00:17<00:00,  1.96s/batch, Точность=25.4, Средняя потеря=1.88]
# Эпоха 11: 100%|██████████| 35/35 [01:06<00:00,  1.89s/batch, Точность=29, Средняя потеря=1.72]
# Тестирование 11: 100%|██████████| 9/9 [00:16<00:00,  1.88s/batch, Точность=22.9, Средняя потеря=1.86]
# Эпоха 12: 100%|██████████| 35/35 [01:06<00:00,  1.90s/batch, Точность=30.7, Средняя потеря=1.68]
# Тестирование 12: 100%|██████████| 9/9 [00:16<00:00,  1.88s/batch, Точность=23.9, Средняя потеря=1.93]
# Эпоха 13: 100%|██████████| 35/35 [01:06<00:00,  1.89s/batch, Точность=30.2, Средняя потеря=1.67]
# Тестирование 13: 100%|██████████| 9/9 [00:17<00:00,  1.96s/batch, Точность=22.5, Средняя потеря=1.92]
# Эпоха 14: 100%|██████████| 35/35 [01:06<00:00,  1.89s/batch, Точность=32.7, Средняя потеря=1.64]
# Тестирование 14: 100%|██████████| 9/9 [00:16<00:00,  1.87s/batch, Точность=24.3, Средняя потеря=1.85]
# Ранняя остановка на эпохе 14 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_mamba_best = Mamba(num_layers = 6, d_input = 1024, d_model = 256, num_classes=7, model_name='jina', pooling='mean').to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "Mamba_jina_9_26.79_checkpoint.pth"))
model_mamba_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# <All keys matched successfully>

# %%
evaluate_metrics(model_mamba_best, test_dataloader)
# Out:
# {'uar': 0.24552962052962052,
#  'war': 0.26785714285714285,
#  'mf1': 0.19263157001240241,
#  'wf1': 0.2077220033450818,
#  'accuracy': 0.26785714285714285}

# %% [markdown]
# #### Mamba + xlm-roberta-base with mean pooling

# %%
mamba = Mamba(model_name='xlm-roberta-base', pooling='mean', num_layers = 6, d_input = 768, d_model = 256, num_classes=7).to(device)
optimizer = optim.AdamW(params = mamba.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(mamba, train_dataloader, test_dataloader, DEVICE, EPOCHS, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [01:42<00:00,  2.93s/batch, Точность=14.3, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:25<00:00,  2.83s/batch, Точность=15.7, Средняя потеря=1.94]
# Эпоха 2: 100%|██████████| 35/35 [01:39<00:00,  2.83s/batch, Точность=14.9, Средняя потеря=1.95]
# Тестирование 2: 100%|██████████| 9/9 [00:26<00:00,  2.93s/batch, Точность=15.7, Средняя потеря=1.94]
# Эпоха 3: 100%|██████████| 35/35 [01:40<00:00,  2.86s/batch, Точность=15.4, Средняя потеря=1.94]
# Тестирование 3: 100%|██████████| 9/9 [00:25<00:00,  2.88s/batch, Точность=15.7, Средняя потеря=1.94]
# Эпоха 4: 100%|██████████| 35/35 [01:40<00:00,  2.87s/batch, Точность=15, Средняя потеря=1.94]
# Тестирование 4: 100%|██████████| 9/9 [00:26<00:00,  2.90s/batch, Точность=15.7, Средняя потеря=1.94]
# Эпоха 5: 100%|██████████| 35/35 [01:39<00:00,  2.85s/batch, Точность=15.1, Средняя потеря=1.94]
# Тестирование 5: 100%|██████████| 9/9 [00:26<00:00,  2.95s/batch, Точность=15.7, Средняя потеря=1.94]
# Эпоха 6: 100%|██████████| 35/35 [01:46<00:00,  3.04s/batch, Точность=15.2, Средняя потеря=1.94]
# Тестирование 6: 100%|██████████| 9/9 [00:25<00:00,  2.79s/batch, Точность=16.1, Средняя потеря=1.94]
# Эпоха 7: 100%|██████████| 35/35 [01:41<00:00,  2.89s/batch, Точность=14.9, Средняя потеря=1.94]
# Тестирование 7: 100%|██████████| 9/9 [00:25<00:00,  2.81s/batch, Точность=16.1, Средняя потеря=1.94]
# Эпоха 8: 100%|██████████| 35/35 [01:39<00:00,  2.84s/batch, Точность=14.9, Средняя потеря=1.94]
# Тестирование 8: 100%|██████████| 9/9 [00:26<00:00,  2.93s/batch, Точность=16.1, Средняя потеря=1.94]
# Эпоха 9: 100%|██████████| 35/35 [01:40<00:00,  2.87s/batch, Точность=15.9, Средняя потеря=1.94]
# Тестирование 9: 100%|██████████| 9/9 [00:25<00:00,  2.88s/batch, Точность=16.1, Средняя потеря=1.94]
# Эпоха 10: 100%|██████████| 35/35 [01:40<00:00,  2.87s/batch, Точность=14.4, Средняя потеря=1.94]
# Тестирование 10: 100%|██████████| 9/9 [00:25<00:00,  2.82s/batch, Точность=16.1, Средняя потеря=1.94]
# Эпоха 11: 100%|██████████| 35/35 [01:38<00:00,  2.82s/batch, Точность=15.9, Средняя потеря=1.94]
# Тестирование 11: 100%|██████████| 9/9 [00:26<00:00,  2.99s/batch, Точность=16.1, Средняя потеря=1.94]
# Ранняя остановка на эпохе 11 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_mamba_best = Mamba(model_name='xlm-roberta-base', pooling='mean', num_layers = 6, d_input = 768, d_model = 256, num_classes=7).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "Mamba_xlm-roberta-base_1_16.07_checkpoint.pth"))
model_mamba_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(mamba, test_dataloader)
# Out:
# {'uar': 0.14285714285714285,
#  'war': 0.16071428571428573,
#  'mf1': 0.039560439560439566,
#  'wf1': 0.04450549450549451}

# %% [markdown]
# #### Mamba + jina

# %%
model_mamba = Mamba(model_name='jina', pooling=None, num_layers = 6, d_input = 1024, d_model = 256, num_classes=7).to(device)
optimizer = optim.AdamW(params = model_mamba.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(model_mamba, train_dataloader, test_dataloader, DEVICE, EPOCHS, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn)
trainer.train(PATH_TO_MODEL)
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# Эпоха 1: 100%|██████████| 35/35 [00:23<00:00,  1.47batch/s, Точность=19.2, Средняя потеря=1.93]
# Тестирование 1: 100%|██████████| 9/9 [00:06<00:00,  1.34batch/s, Точность=27.1, Средняя потеря=1.85]
# Эпоха 2: 100%|██████████| 35/35 [00:23<00:00,  1.48batch/s, Точность=31, Средняя потеря=1.77]
# Тестирование 2: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=26.1, Средняя потеря=1.83]
# Эпоха 3: 100%|██████████| 35/35 [00:23<00:00,  1.46batch/s, Точность=36.1, Средняя потеря=1.66]
# Тестирование 3: 100%|██████████| 9/9 [00:06<00:00,  1.35batch/s, Точность=29.3, Средняя потеря=1.86]
# Эпоха 4: 100%|██████████| 35/35 [00:23<00:00,  1.48batch/s, Точность=39.9, Средняя потеря=1.58]
# Тестирование 4: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=33.2, Средняя потеря=1.72]
# Эпоха 5: 100%|██████████| 35/35 [00:23<00:00,  1.46batch/s, Точность=47.9, Средняя потеря=1.45]
# Тестирование 5: 100%|██████████| 9/9 [00:06<00:00,  1.36batch/s, Точность=31.4, Средняя потеря=1.82]
# Эпоха 6: 100%|██████████| 35/35 [00:23<00:00,  1.48batch/s, Точность=48.6, Средняя потеря=1.39]
# Тестирование 6: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=34.3, Средняя потеря=2.06]
# Эпоха 7: 100%|██████████| 35/35 [00:23<00:00,  1.46batch/s, Точность=52.8, Средняя потеря=1.29]
# Тестирование 7: 100%|██████████| 9/9 [00:06<00:00,  1.35batch/s, Точность=30.7, Средняя потеря=1.9]
# Эпоха 8: 100%|██████████| 35/35 [00:23<00:00,  1.47batch/s, Точность=53.5, Средняя потеря=1.24]
# Тестирование 8: 100%|██████████| 9/9 [00:06<00:00,  1.46batch/s, Точность=35, Средняя потеря=1.94]
# Эпоха 9: 100%|██████████| 35/35 [00:23<00:00,  1.46batch/s, Точность=54, Средняя потеря=1.24]
# Тестирование 9: 100%|██████████| 9/9 [00:06<00:00,  1.36batch/s, Точность=34.6, Средняя потеря=1.82]
# Эпоха 10: 100%|██████████| 35/35 [00:23<00:00,  1.47batch/s, Точность=57.1, Средняя потеря=1.19]
# Тестирование 10: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=31.4, Средняя потеря=2]
# Эпоха 11: 100%|██████████| 35/35 [00:24<00:00,  1.46batch/s, Точность=56.8, Средняя потеря=1.17]
# Тестирование 11: 100%|██████████| 9/9 [00:06<00:00,  1.41batch/s, Точность=32.5, Средняя потеря=1.99]
# Эпоха 12: 100%|██████████| 35/35 [00:23<00:00,  1.47batch/s, Точность=59.1, Средняя потеря=1.13]
# Тестирование 12: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=36.1, Средняя потеря=2.02]
# Эпоха 13: 100%|██████████| 35/35 [00:23<00:00,  1.46batch/s, Точность=59.1, Средняя потеря=1.09]
# Тестирование 13: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=36.8, Средняя потеря=1.95]
# Эпоха 14: 100%|██████████| 35/35 [00:24<00:00,  1.45batch/s, Точность=62.5, Средняя потеря=1.07]
# Тестирование 14: 100%|██████████| 9/9 [00:06<00:00,  1.46batch/s, Точность=40, Средняя потеря=2.09]
# Эпоха 15: 100%|██████████| 35/35 [00:23<00:00,  1.47batch/s, Точность=61.1, Средняя потеря=1.05]
# Тестирование 15: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=34.3, Средняя потеря=2.05]
# Эпоха 16: 100%|██████████| 35/35 [00:24<00:00,  1.44batch/s, Точность=60.4, Средняя потеря=1.08]
# Тестирование 16: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=30.7, Средняя потеря=2.09]
# Эпоха 17: 100%|██████████| 35/35 [00:23<00:00,  1.46batch/s, Точность=64.6, Средняя потеря=1.01]
# Тестирование 17: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=34.3, Средняя потеря=2.25]
# Эпоха 18: 100%|██████████| 35/35 [00:24<00:00,  1.44batch/s, Точность=63.2, Средняя потеря=0.966]
# Тестирование 18: 100%|██████████| 9/9 [00:06<00:00,  1.46batch/s, Точность=34.6, Средняя потеря=2.23]
# Эпоха 19: 100%|██████████| 35/35 [00:23<00:00,  1.46batch/s, Точность=62.3, Средняя потеря=0.997]
# Тестирование 19: 100%|██████████| 9/9 [00:06<00:00,  1.47batch/s, Точность=36.1, Средняя потеря=2.51]
# Ранняя остановка на эпохе 19 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_mamba_best = Mamba(model_name='jina', pooling=None, num_layers = 6, d_input = 1024, d_model = 256, num_classes=7).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "Mamba_jina_emb_14_40.0_checkpoint.pth"))
model_mamba_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# <All keys matched successfully>

# %%
evaluate_metrics(model_mamba_best, test_dataloader)
# Out:
# {'uar': 0.39391791826002354,
#  'war': 0.4,
#  'mf1': 0.39486657962848437,
#  'wf1': 0.39949080372889895}

# %% [markdown]
# #### Mamba + xlm-roberta-base

# %%
mamba = Mamba(model_name='xlm-roberta-base', pooling=None, num_layers = 6, d_input = 768, d_model = 256, num_classes=7).to(device)
optimizer = optim.AdamW(params = mamba.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(mamba, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:20<00:00,  1.72batch/s, Точность=13.4, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:04<00:00,  1.90batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 2: 100%|██████████| 35/35 [00:18<00:00,  1.84batch/s, Точность=14.1, Средняя потеря=1.95]
# Тестирование 2: 100%|██████████| 9/9 [00:04<00:00,  1.92batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 3: 100%|██████████| 35/35 [00:19<00:00,  1.83batch/s, Точность=15.3, Средняя потеря=1.94]
# Тестирование 3: 100%|██████████| 9/9 [00:04<00:00,  1.90batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 4: 100%|██████████| 35/35 [00:19<00:00,  1.79batch/s, Точность=14.5, Средняя потеря=1.94]
# Тестирование 4: 100%|██████████| 9/9 [00:04<00:00,  1.92batch/s, Точность=17.9, Средняя потеря=1.94]
# Эпоха 5: 100%|██████████| 35/35 [00:19<00:00,  1.84batch/s, Точность=15.1, Средняя потеря=1.94]
# Тестирование 5: 100%|██████████| 9/9 [00:04<00:00,  1.89batch/s, Точность=14.6, Средняя потеря=1.94]
# Эпоха 6: 100%|██████████| 35/35 [00:19<00:00,  1.79batch/s, Точность=17.5, Средняя потеря=1.94]
# Тестирование 6: 100%|██████████| 9/9 [00:04<00:00,  1.92batch/s, Точность=14.6, Средняя потеря=1.94]
# Эпоха 7: 100%|██████████| 35/35 [00:19<00:00,  1.84batch/s, Точность=16.7, Средняя потеря=1.94]
# Тестирование 7: 100%|██████████| 9/9 [00:04<00:00,  1.91batch/s, Точность=13.9, Средняя потеря=1.95]
# Эпоха 8: 100%|██████████| 35/35 [00:19<00:00,  1.83batch/s, Точность=16.8, Средняя потеря=1.93]
# Тестирование 8: 100%|██████████| 9/9 [00:04<00:00,  1.90batch/s, Точность=15.7, Средняя потеря=1.98]
# Эпоха 9: 100%|██████████| 35/35 [00:19<00:00,  1.79batch/s, Точность=17.4, Средняя потеря=1.93]
# Тестирование 9: 100%|██████████| 9/9 [00:04<00:00,  1.90batch/s, Точность=16.4, Средняя потеря=1.96]
# Эпоха 10: 100%|██████████| 35/35 [00:19<00:00,  1.84batch/s, Точность=19.4, Средняя потеря=1.93]
# Тестирование 10: 100%|██████████| 9/9 [00:04<00:00,  1.91batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 11: 100%|██████████| 35/35 [00:18<00:00,  1.85batch/s, Точность=19.9, Средняя потеря=1.92]
# Тестирование 11: 100%|██████████| 9/9 [00:05<00:00,  1.70batch/s, Точность=19.3, Средняя потеря=1.93]
# Эпоха 12: 100%|██████████| 35/35 [00:19<00:00,  1.84batch/s, Точность=21.3, Средняя потеря=1.9]
# Тестирование 12: 100%|██████████| 9/9 [00:04<00:00,  1.92batch/s, Точность=23.9, Средняя потеря=1.89]
# Эпоха 13: 100%|██████████| 35/35 [00:19<00:00,  1.83batch/s, Точность=21.9, Средняя потеря=1.88]
# Тестирование 13: 100%|██████████| 9/9 [00:04<00:00,  1.91batch/s, Точность=16.4, Средняя потеря=1.93]
# Эпоха 14: 100%|██████████| 35/35 [00:19<00:00,  1.80batch/s, Точность=22.3, Средняя потеря=1.89]
# Тестирование 14: 100%|██████████| 9/9 [00:04<00:00,  1.88batch/s, Точность=24.6, Средняя потеря=1.88]
# Эпоха 15: 100%|██████████| 35/35 [00:18<00:00,  1.84batch/s, Точность=22.7, Средняя потеря=1.87]
# Тестирование 15: 100%|██████████| 9/9 [00:04<00:00,  1.92batch/s, Точность=23.6, Средняя потеря=1.87]
# Эпоха 16: 100%|██████████| 35/35 [00:19<00:00,  1.84batch/s, Точность=22.4, Средняя потеря=1.87]
# Тестирование 16: 100%|██████████| 9/9 [00:04<00:00,  1.86batch/s, Точность=23.6, Средняя потеря=1.87]
# Эпоха 17: 100%|██████████| 35/35 [00:19<00:00,  1.82batch/s, Точность=23.6, Средняя потеря=1.85]
# Тестирование 17: 100%|██████████| 9/9 [00:04<00:00,  1.92batch/s, Точность=17.1, Средняя потеря=1.91]
# Эпоха 18: 100%|██████████| 35/35 [00:19<00:00,  1.84batch/s, Точность=22.5, Средняя потеря=1.86]
# Тестирование 18: 100%|██████████| 9/9 [00:04<00:00,  1.90batch/s, Точность=20.4, Средняя потеря=1.88]
# Эпоха 19: 100%|██████████| 35/35 [00:19<00:00,  1.79batch/s, Точность=24.6, Средняя потеря=1.83]
# Тестирование 19: 100%|██████████| 9/9 [00:04<00:00,  1.89batch/s, Точность=19.3, Средняя потеря=1.93]
# Эпоха 20: 100%|██████████| 35/35 [00:19<00:00,  1.84batch/s, Точность=24.1, Средняя потеря=1.84]
# Тестирование 20: 100%|██████████| 9/9 [00:04<00:00,  1.92batch/s, Точность=22.5, Средняя потеря=1.86]
# Эпоха 21: 100%|██████████| 35/35 [00:19<00:00,  1.84batch/s, Точность=25.2, Средняя потеря=1.8]
# Тестирование 21: 100%|██████████| 9/9 [00:04<00:00,  1.90batch/s, Точность=22.9, Средняя потеря=2.02]
# Эпоха 22: 100%|██████████| 35/35 [00:19<00:00,  1.79batch/s, Точность=25.3, Средняя потеря=1.81]
# Тестирование 22: 100%|██████████| 9/9 [00:04<00:00,  1.91batch/s, Точность=20, Средняя потеря=1.87]
# Эпоха 23: 100%|██████████| 35/35 [00:19<00:00,  1.81batch/s, Точность=24.9, Средняя потеря=1.8]
# Тестирование 23: 100%|██████████| 9/9 [00:04<00:00,  1.92batch/s, Точность=22.9, Средняя потеря=1.85]
# Эпоха 24: 100%|██████████| 35/35 [00:19<00:00,  1.79batch/s, Точность=24.5, Средняя потеря=1.79]
# Тестирование 24: 100%|██████████| 9/9 [00:04<00:00,  1.91batch/s, Точность=22.9, Средняя потеря=1.91]
# Ранняя остановка на эпохе 24 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_mamba_best = Mamba(model_name='xlm-roberta-base', pooling=None, num_layers = 6, d_input = 768, d_model = 256, num_classes=7).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "Mamba_xlm-roberta-base_emb_14_24.64_checkpoint.pth"))
model_mamba_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_mamba_best, test_dataloader)
# Out:
# {'uar': 0.2253056884635832,
#  'war': 0.24642857142857144,
#  'mf1': 0.15435643687939335,
#  'wf1': 0.1656900287729732,
#  'accuracy': 0.24642857142857144}

# %% [markdown]
# #### Mamba + canine-c with mean pooling

# %%
mamba = Mamba(model_name='canine-c', pooling='mean', num_layers = 6, d_input = 768, d_model = 256, num_classes=7).to(device)
optimizer = optim.AdamW(params = mamba.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(mamba, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:03<00:00, 11.34batch/s, Точность=14.6, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:01<00:00,  7.91batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 2: 100%|██████████| 35/35 [00:02<00:00, 12.10batch/s, Точность=15.4, Средняя потеря=1.94]
# Тестирование 2: 100%|██████████| 9/9 [00:00<00:00, 11.40batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 3: 100%|██████████| 35/35 [00:02<00:00, 12.34batch/s, Точность=14.9, Средняя потеря=1.94]
# Тестирование 3: 100%|██████████| 9/9 [00:00<00:00, 12.24batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 4: 100%|██████████| 35/35 [00:02<00:00, 13.11batch/s, Точность=17.4, Средняя потеря=1.94]
# Тестирование 4: 100%|██████████| 9/9 [00:00<00:00, 12.45batch/s, Точность=17.1, Средняя потеря=1.94]
# Эпоха 5: 100%|██████████| 35/35 [00:02<00:00, 13.10batch/s, Точность=20.2, Средняя потеря=1.91]
# Тестирование 5: 100%|██████████| 9/9 [00:00<00:00, 12.61batch/s, Точность=21.8, Средняя потеря=1.92]
# Эпоха 6: 100%|██████████| 35/35 [00:02<00:00, 12.54batch/s, Точность=21.1, Средняя потеря=1.91]
# Тестирование 6: 100%|██████████| 9/9 [00:00<00:00, 12.79batch/s, Точность=19.6, Средняя потеря=1.92]
# Эпоха 7: 100%|██████████| 35/35 [00:02<00:00, 12.56batch/s, Точность=21.9, Средняя потеря=1.89]
# Тестирование 7: 100%|██████████| 9/9 [00:00<00:00, 12.43batch/s, Точность=21.8, Средняя потеря=1.92]
# Эпоха 8: 100%|██████████| 35/35 [00:02<00:00, 13.04batch/s, Точность=23.4, Средняя потеря=1.87]
# Тестирование 8: 100%|██████████| 9/9 [00:00<00:00, 12.22batch/s, Точность=19.6, Средняя потеря=1.93]
# Эпоха 9: 100%|██████████| 35/35 [00:02<00:00, 12.32batch/s, Точность=22.2, Средняя потеря=1.88]
# Тестирование 9: 100%|██████████| 9/9 [00:00<00:00, 10.99batch/s, Точность=21.8, Средняя потеря=1.92]
# Эпоха 10: 100%|██████████| 35/35 [00:02<00:00, 12.66batch/s, Точность=23.8, Средняя потеря=1.86]
# Тестирование 10: 100%|██████████| 9/9 [00:00<00:00, 12.29batch/s, Точность=21.1, Средняя потеря=1.93]
# Эпоха 11: 100%|██████████| 35/35 [00:02<00:00, 12.68batch/s, Точность=24.4, Средняя потеря=1.86]
# Тестирование 11: 100%|██████████| 9/9 [00:00<00:00, 13.03batch/s, Точность=20.7, Средняя потеря=2.01]
# Эпоха 12: 100%|██████████| 35/35 [00:02<00:00, 12.59batch/s, Точность=24.4, Средняя потеря=1.85]
# Тестирование 12: 100%|██████████| 9/9 [00:00<00:00, 11.99batch/s, Точность=22.5, Средняя потеря=1.95]
# Эпоха 13: 100%|██████████| 35/35 [00:02<00:00, 13.20batch/s, Точность=24, Средняя потеря=1.85]
# Тестирование 13: 100%|██████████| 9/9 [00:00<00:00, 11.54batch/s, Точность=20, Средняя потеря=1.93]
# Эпоха 14: 100%|██████████| 35/35 [00:02<00:00, 13.03batch/s, Точность=23.9, Средняя потеря=1.84]
# Тестирование 14: 100%|██████████| 9/9 [00:00<00:00, 11.95batch/s, Точность=20.7, Средняя потеря=2]
# Эпоха 15: 100%|██████████| 35/35 [00:02<00:00, 12.85batch/s, Точность=25.2, Средняя потеря=1.83]
# Тестирование 15: 100%|██████████| 9/9 [00:00<00:00, 13.46batch/s, Точность=19.6, Средняя потеря=1.99]
# Эпоха 16: 100%|██████████| 35/35 [00:02<00:00, 13.10batch/s, Точность=24.8, Средняя потеря=1.85]
# Тестирование 16: 100%|██████████| 9/9 [00:00<00:00, 12.38batch/s, Точность=17.9, Средняя потеря=2.04]
# Эпоха 17: 100%|██████████| 35/35 [00:02<00:00, 12.65batch/s, Точность=25, Средняя потеря=1.84]
# Тестирование 17: 100%|██████████| 9/9 [00:00<00:00, 11.07batch/s, Точность=18.9, Средняя потеря=1.95]
# Эпоха 18: 100%|██████████| 35/35 [00:02<00:00, 12.82batch/s, Точность=23.4, Средняя потеря=1.84]
# Тестирование 18: 100%|██████████| 9/9 [00:00<00:00, 11.85batch/s, Точность=22.5, Средняя потеря=1.97]
# Эпоха 19: 100%|██████████| 35/35 [00:03<00:00,  9.22batch/s, Точность=25.9, Средняя потеря=1.83]
# Тестирование 19: 100%|██████████| 9/9 [00:00<00:00, 11.29batch/s, Точность=20.4, Средняя потеря=1.93]
# Эпоха 20: 100%|██████████| 35/35 [00:02<00:00, 12.47batch/s, Точность=25.7, Средняя потеря=1.82]
# Тестирование 20: 100%|██████████| 9/9 [00:00<00:00, 12.81batch/s, Точность=18.9, Средняя потеря=2.03]
# Эпоха 21: 100%|██████████| 35/35 [00:02<00:00, 12.74batch/s, Точность=26.6, Средняя потеря=1.81]
# Тестирование 21: 100%|██████████| 9/9 [00:00<00:00, 12.32batch/s, Точность=19.6, Средняя потеря=2.02]
# Эпоха 22: 100%|██████████| 35/35 [00:02<00:00, 12.51batch/s, Точность=27.7, Средняя потеря=1.8]
# Тестирование 22: 100%|██████████| 9/9 [00:00<00:00, 11.49batch/s, Точность=19.6, Средняя потеря=2.03]
# Ранняя остановка на эпохе 22 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_mamba_best = Mamba(model_name='canine-c', pooling='mean', num_layers = 6, d_input = 768, d_model = 256, num_classes=7).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "Mamba_canine-c_12_22.5_checkpoint.pth"))
model_mamba_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_mamba_best, test_dataloader)
# Out:
# {'uar': 0.20202020202020204,
#  'war': 0.225,
#  'mf1': 0.12115834984687444,
#  'wf1': 0.13452418483156187}

# %% [markdown]
# #### Mamba + canine-c

# %%
mamba = Mamba(model_name='canine-c', pooling=None, num_layers = 6, d_input = 768, d_model = 256, num_classes=7).to(device)
optimizer = optim.AdamW(params = mamba.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(mamba, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:22<00:00,  1.56batch/s, Точность=15.5, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:05<00:00,  1.68batch/s, Точность=19.6, Средняя потеря=1.92]
# Эпоха 2: 100%|██████████| 35/35 [00:22<00:00,  1.59batch/s, Точность=20.2, Средняя потеря=1.92]
# Тестирование 2: 100%|██████████| 9/9 [00:05<00:00,  1.69batch/s, Точность=21.8, Средняя потеря=1.92]
# Эпоха 3: 100%|██████████| 35/35 [00:22<00:00,  1.58batch/s, Точность=19.8, Средняя потеря=1.91]
# Тестирование 3: 100%|██████████| 9/9 [00:05<00:00,  1.69batch/s, Точность=20.7, Средняя потеря=1.92]
# Эпоха 4: 100%|██████████| 35/35 [00:22<00:00,  1.59batch/s, Точность=20.9, Средняя потеря=1.89]
# Тестирование 4: 100%|██████████| 9/9 [00:05<00:00,  1.52batch/s, Точность=18.2, Средняя потеря=1.95]
# Эпоха 5: 100%|██████████| 35/35 [00:22<00:00,  1.58batch/s, Точность=22.2, Средняя потеря=1.87]
# Тестирование 5: 100%|██████████| 9/9 [00:05<00:00,  1.69batch/s, Точность=21.1, Средняя потеря=1.93]
# Эпоха 6: 100%|██████████| 35/35 [00:22<00:00,  1.59batch/s, Точность=24.5, Средняя потеря=1.87]
# Тестирование 6: 100%|██████████| 9/9 [00:05<00:00,  1.68batch/s, Точность=17.9, Средняя потеря=1.95]
# Эпоха 7: 100%|██████████| 35/35 [00:22<00:00,  1.54batch/s, Точность=22.3, Средняя потеря=1.86]
# Тестирование 7: 100%|██████████| 9/9 [00:05<00:00,  1.67batch/s, Точность=20.7, Средняя потеря=1.93]
# Эпоха 8: 100%|██████████| 35/35 [00:22<00:00,  1.59batch/s, Точность=25.5, Средняя потеря=1.83]
# Тестирование 8: 100%|██████████| 9/9 [00:05<00:00,  1.66batch/s, Точность=23.2, Средняя потеря=1.96]
# Эпоха 9: 100%|██████████| 35/35 [00:22<00:00,  1.54batch/s, Точность=24.9, Средняя потеря=1.84]
# Тестирование 9: 100%|██████████| 9/9 [00:05<00:00,  1.66batch/s, Точность=21.1, Средняя потеря=1.95]
# Эпоха 10: 100%|██████████| 35/35 [00:22<00:00,  1.59batch/s, Точность=25.7, Средняя потеря=1.83]
# Тестирование 10: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=20.7, Средняя потеря=1.94]
# Эпоха 11: 100%|██████████| 35/35 [00:22<00:00,  1.54batch/s, Точность=24.7, Средняя потеря=1.83]
# Тестирование 11: 100%|██████████| 9/9 [00:05<00:00,  1.69batch/s, Точность=19.3, Средняя потеря=1.92]
# Эпоха 12: 100%|██████████| 35/35 [00:22<00:00,  1.57batch/s, Точность=27.1, Средняя потеря=1.8]
# Эпоха 16: 100%|██████████| 35/35 [00:22<00:00,  1.59batch/s, Точность=30.4, Средняя потеря=1.72]
# Тестирование 16: 100%|██████████| 9/9 [00:05<00:00,  1.69batch/s, Точность=19.6, Средняя потеря=2.05]
# Эпоха 17: 100%|██████████| 35/35 [00:21<00:00,  1.59batch/s, Точность=32.5, Средняя потеря=1.69]
# Тестирование 17: 100%|██████████| 9/9 [00:05<00:00,  1.69batch/s, Точность=20.4, Средняя потеря=2.15]
# Эпоха 18: 100%|██████████| 35/35 [00:22<00:00,  1.59batch/s, Точность=30.1, Средняя потеря=1.7]
# Тестирование 18: 100%|██████████| 9/9 [00:05<00:00,  1.67batch/s, Точность=20.4, Средняя потеря=2.21]
# Ранняя остановка на эпохе 18 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_mamba_best = Mamba(model_name='canine-c', pooling=None, num_layers = 6, d_input = 768, d_model = 256, num_classes=7).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "Mamba_canine-c_emb_8_23.21_checkpoint.pth"))
model_mamba_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_mamba_best, test_dataloader)
# Out:
# {'uar': 0.22442659679501784,
#  'war': 0.2392857142857143,
#  'mf1': 0.17037981614406097,
#  'wf1': 0.17986244988053854}

# %% [markdown]
# ### LSTM

# %%
class LSTMClassifier(nn.Module):
    def __init__(self, num_classes, model_name='jina', pooling=None, input_size = 1024, hidden_size = 32, num_layers = 2):
        super(LSTMClassifier, self).__init__()
        embed = Embedding(model_name, pooling)
        self.embedding = embed.get_embeddings
        self.model_name = model_name
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(
            input_size = input_size,
            hidden_size = hidden_size,
            num_layers = num_layers,
            batch_first = True
        )
        self.fc = nn.Linear(hidden_size, num_classes)
        
    def forward(self, x):
        x = torch.tensor(self.embedding(x)).to(device)
        h0, c0 = torch.zeros(self.num_layers, len(x), self.hidden_size).to(device), torch.zeros(self.num_layers, len(x), self.hidden_size).to(device)
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1])
        return out

# %% [markdown]
# #### LSTM + jina with mean pooling

# %%
lstm = LSTMClassifier(num_classes = 7, model_name='jina', pooling='mean').to(device)
optimizer = optim.AdamW(params = lstm.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(lstm, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# Эпоха 1: 100%|██████████| 35/35 [00:17<00:00,  2.06batch/s, Точность=14.1, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:04<00:00,  2.03batch/s, Точность=11.8, Средняя потеря=1.97]
# Эпоха 2: 100%|██████████| 35/35 [00:16<00:00,  2.09batch/s, Точность=14.7, Средняя потеря=1.95]
# Тестирование 2: 100%|██████████| 9/9 [00:04<00:00,  2.08batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 3: 100%|██████████| 35/35 [00:17<00:00,  2.04batch/s, Точность=15.7, Средняя потеря=1.95]
# Тестирование 3: 100%|██████████| 9/9 [00:04<00:00,  2.04batch/s, Точность=17.1, Средняя потеря=1.95]
# Эпоха 4: 100%|██████████| 35/35 [00:16<00:00,  2.09batch/s, Точность=14.8, Средняя потеря=1.95]
# Тестирование 4: 100%|██████████| 9/9 [00:04<00:00,  2.08batch/s, Точность=12.9, Средняя потеря=1.96]
# Эпоха 5: 100%|██████████| 35/35 [00:16<00:00,  2.09batch/s, Точность=16.7, Средняя потеря=1.95]
# Тестирование 5: 100%|██████████| 9/9 [00:04<00:00,  2.12batch/s, Точность=11.8, Средняя потеря=1.95]
# Эпоха 6: 100%|██████████| 35/35 [00:17<00:00,  2.04batch/s, Точность=15, Средняя потеря=1.95]
# Тестирование 6: 100%|██████████| 9/9 [00:04<00:00,  2.05batch/s, Точность=14.6, Средняя потеря=1.95]
# Эпоха 7: 100%|██████████| 35/35 [00:17<00:00,  2.04batch/s, Точность=16.5, Средняя потеря=1.95]
# Тестирование 7: 100%|██████████| 9/9 [00:04<00:00,  2.03batch/s, Точность=17.9, Средняя потеря=1.95]
# Эпоха 8: 100%|██████████| 35/35 [00:17<00:00,  2.05batch/s, Точность=15.2, Средняя потеря=1.95]
# Тестирование 8: 100%|██████████| 9/9 [00:04<00:00,  2.02batch/s, Точность=13.6, Средняя потеря=1.96]
# Эпоха 9: 100%|██████████| 35/35 [00:17<00:00,  2.01batch/s, Точность=16.5, Средняя потеря=1.95]
# Тестирование 9: 100%|██████████| 9/9 [00:04<00:00,  2.15batch/s, Точность=13.2, Средняя потеря=1.95]
# Эпоха 10: 100%|██████████| 35/35 [00:16<00:00,  2.14batch/s, Точность=15.4, Средняя потеря=1.95]
# Тестирование 10: 100%|██████████| 9/9 [00:04<00:00,  2.12batch/s, Точность=15.4, Средняя потеря=1.95]
# Эпоха 11: 100%|██████████| 35/35 [00:16<00:00,  2.08batch/s, Точность=14.7, Средняя потеря=1.95]
# Тестирование 11: 100%|██████████| 9/9 [00:04<00:00,  1.84batch/s, Точность=14.3, Средняя потеря=1.96]
# Эпоха 12: 100%|██████████| 35/35 [00:16<00:00,  2.08batch/s, Точность=13.6, Средняя потеря=1.95]
# Тестирование 12: 100%|██████████| 9/9 [00:04<00:00,  2.05batch/s, Точность=18.9, Средняя потеря=1.94]
# Эпоха 13: 100%|██████████| 35/35 [00:16<00:00,  2.09batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 13: 100%|██████████| 9/9 [00:04<00:00,  2.05batch/s, Точность=17.1, Средняя потеря=1.94]
# Эпоха 14: 100%|██████████| 35/35 [00:16<00:00,  2.08batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 14: 100%|██████████| 9/9 [00:04<00:00,  1.86batch/s, Точность=16.4, Средняя потеря=1.95]
# Эпоха 15: 100%|██████████| 35/35 [00:16<00:00,  2.09batch/s, Точность=16, Средняя потеря=1.95]
# Тестирование 15: 100%|██████████| 9/9 [00:04<00:00,  2.05batch/s, Точность=13.9, Средняя потеря=1.95]
# Эпоха 16: 100%|██████████| 35/35 [00:16<00:00,  2.06batch/s, Точность=16.1, Средняя потеря=1.95]
# Тестирование 16: 100%|██████████| 9/9 [00:04<00:00,  2.06batch/s, Точность=11.8, Средняя потеря=1.96]
# Эпоха 17: 100%|██████████| 35/35 [00:17<00:00,  2.05batch/s, Точность=15.3, Средняя потеря=1.95]
# Тестирование 17: 100%|██████████| 9/9 [00:04<00:00,  2.10batch/s, Точность=12.9, Средняя потеря=1.95]
# Эпоха 18: 100%|██████████| 35/35 [00:16<00:00,  2.11batch/s, Точность=13.2, Средняя потеря=1.96]
# Тестирование 18: 100%|██████████| 9/9 [00:04<00:00,  2.07batch/s, Точность=13.9, Средняя потеря=1.96]
# Эпоха 19: 100%|██████████| 35/35 [00:16<00:00,  2.11batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 19: 100%|██████████| 9/9 [00:04<00:00,  2.08batch/s, Точность=15.4, Средняя потеря=1.96]
# Эпоха 20: 100%|██████████| 35/35 [00:15<00:00,  2.21batch/s, Точность=15.6, Средняя потеря=1.95]
# Тестирование 20: 100%|██████████| 9/9 [00:04<00:00,  2.19batch/s, Точность=15.7, Средняя потеря=1.95]
# Эпоха 21: 100%|██████████| 35/35 [00:15<00:00,  2.21batch/s, Точность=16.2, Средняя потеря=1.95]
# Тестирование 21: 100%|██████████| 9/9 [00:04<00:00,  2.15batch/s, Точность=17.5, Средняя потеря=1.95]
# Эпоха 22: 100%|██████████| 35/35 [00:15<00:00,  2.22batch/s, Точность=15.6, Средняя потеря=1.95]
# Тестирование 22: 100%|██████████| 9/9 [00:04<00:00,  2.19batch/s, Точность=15.7, Средняя потеря=1.95]
# Ранняя остановка на эпохе 22 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_lstm_best = LSTMClassifier(num_classes = 7, model_name='jina', pooling='mean').to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "LSTMClassifier_jina_12_18.93_checkpoint.pth"))
model_lstm_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# <All keys matched successfully>

# %%
evaluate_metrics(model_lstm_best, test_dataloader)
# Out:
# {'uar': 0.17729936019409703,
#  'war': 0.18928571428571428,
#  'mf1': 0.13995055322622701,
#  'wf1': 0.14825675852559023,
#  'accuracy': 0.18928571428571428}

# %% [markdown]
# #### LSTM + jina

# %%
lstm = LSTMClassifier(num_classes = 7, model_name='jina', pooling=None).to(device)
optimizer = optim.AdamW(params = lstm.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(lstm, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# Эпоха 1: 100%|██████████| 35/35 [00:06<00:00,  5.67batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:01<00:00,  5.61batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 2: 100%|██████████| 35/35 [00:06<00:00,  5.76batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 2: 100%|██████████| 9/9 [00:01<00:00,  5.63batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 3: 100%|██████████| 35/35 [00:06<00:00,  5.69batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 3: 100%|██████████| 9/9 [00:01<00:00,  5.72batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 4: 100%|██████████| 35/35 [00:05<00:00,  5.85batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 4: 100%|██████████| 9/9 [00:01<00:00,  5.62batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 5: 100%|██████████| 35/35 [00:06<00:00,  5.12batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 5: 100%|██████████| 9/9 [00:01<00:00,  5.71batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 6: 100%|██████████| 35/35 [00:06<00:00,  5.75batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 6: 100%|██████████| 9/9 [00:01<00:00,  5.63batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 7: 100%|██████████| 35/35 [00:06<00:00,  5.82batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 7: 100%|██████████| 9/9 [00:01<00:00,  5.63batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 8: 100%|██████████| 35/35 [00:06<00:00,  5.81batch/s, Точность=14.1, Средняя потеря=1.95]
# Тестирование 8: 100%|██████████| 9/9 [00:01<00:00,  5.70batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 9: 100%|██████████| 35/35 [00:06<00:00,  5.77batch/s, Точность=14.3, Средняя потеря=1.95]
# Тестирование 9: 100%|██████████| 9/9 [00:01<00:00,  5.72batch/s, Точность=14.3, Средняя потеря=1.94]
# Эпоха 10: 100%|██████████| 35/35 [00:06<00:00,  5.82batch/s, Точность=14.4, Средняя потеря=1.95]
# Тестирование 10: 100%|██████████| 9/9 [00:01<00:00,  5.67batch/s, Точность=14.6, Средняя потеря=1.94]
# Эпоха 11: 100%|██████████| 35/35 [00:06<00:00,  5.77batch/s, Точность=14.3, Средняя потеря=1.94]
# Тестирование 11: 100%|██████████| 9/9 [00:01<00:00,  5.42batch/s, Точность=14.6, Средняя потеря=1.94]
# Эпоха 12: 100%|██████████| 35/35 [00:06<00:00,  5.74batch/s, Точность=14.3, Средняя потеря=1.94]
# Тестирование 12: 100%|██████████| 9/9 [00:01<00:00,  5.63batch/s, Точность=14.3, Средняя потеря=1.94]
# Эпоха 13: 100%|██████████| 35/35 [00:06<00:00,  5.10batch/s, Точность=14.6, Средняя потеря=1.94]
# Тестирование 13: 100%|██████████| 9/9 [00:01<00:00,  5.64batch/s, Точность=14.3, Средняя потеря=1.94]
# Эпоха 14: 100%|██████████| 35/35 [00:06<00:00,  5.74batch/s, Точность=14.2, Средняя потеря=1.94]
# Тестирование 14: 100%|██████████| 9/9 [00:01<00:00,  5.69batch/s, Точность=14.3, Средняя потеря=1.94]
# Эпоха 15: 100%|██████████| 35/35 [00:06<00:00,  5.79batch/s, Точность=14.7, Средняя потеря=1.94]
# Тестирование 15: 100%|██████████| 9/9 [00:01<00:00,  5.71batch/s, Точность=14.3, Средняя потеря=1.94]
# Эпоха 16: 100%|██████████| 35/35 [00:06<00:00,  5.72batch/s, Точность=15.1, Средняя потеря=1.94]
# Тестирование 16: 100%|██████████| 9/9 [00:01<00:00,  5.66batch/s, Точность=15.4, Средняя потеря=1.94]
# Эпоха 17: 100%|██████████| 35/35 [00:06<00:00,  5.79batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 17: 100%|██████████| 9/9 [00:01<00:00,  5.65batch/s, Точность=15, Средняя потеря=1.94]
# Эпоха 18: 100%|██████████| 35/35 [00:06<00:00,  5.77batch/s, Точность=14.3, Средняя потеря=1.94]
# Тестирование 18: 100%|██████████| 9/9 [00:01<00:00,  5.46batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 19: 100%|██████████| 35/35 [00:05<00:00,  5.89batch/s, Точность=16.1, Средняя потеря=1.94]
# Тестирование 19: 100%|██████████| 9/9 [00:01<00:00,  5.68batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 20: 100%|██████████| 35/35 [00:06<00:00,  5.63batch/s, Точность=15.8, Средняя потеря=1.94]
# Тестирование 20: 100%|██████████| 9/9 [00:01<00:00,  5.63batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 21: 100%|██████████| 35/35 [00:06<00:00,  5.05batch/s, Точность=15.8, Средняя потеря=1.94]
# Тестирование 21: 100%|██████████| 9/9 [00:01<00:00,  5.73batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 22: 100%|██████████| 35/35 [00:06<00:00,  5.70batch/s, Точность=15.1, Средняя потеря=1.94]
# Тестирование 22: 100%|██████████| 9/9 [00:01<00:00,  5.45batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 23: 100%|██████████| 35/35 [00:06<00:00,  5.80batch/s, Точность=15.1, Средняя потеря=1.94]
# Тестирование 23: 100%|██████████| 9/9 [00:01<00:00,  5.69batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 24: 100%|██████████| 35/35 [00:06<00:00,  5.69batch/s, Точность=14.6, Средняя потеря=1.94]
# Тестирование 24: 100%|██████████| 9/9 [00:01<00:00,  5.58batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 25: 100%|██████████| 35/35 [00:06<00:00,  5.69batch/s, Точность=15.2, Средняя потеря=1.94]
# Тестирование 25: 100%|██████████| 9/9 [00:01<00:00,  5.68batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 26: 100%|██████████| 35/35 [00:06<00:00,  5.70batch/s, Точность=16.4, Средняя потеря=1.94]
# Тестирование 26: 100%|██████████| 9/9 [00:01<00:00,  5.62batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 27: 100%|██████████| 35/35 [00:06<00:00,  5.71batch/s, Точность=15.9, Средняя потеря=1.94]
# Тестирование 27: 100%|██████████| 9/9 [00:01<00:00,  5.68batch/s, Точность=15.4, Средняя потеря=1.94]
# Эпоха 28: 100%|██████████| 35/35 [00:06<00:00,  5.68batch/s, Точность=15.1, Средняя потеря=1.94]
# Тестирование 28: 100%|██████████| 9/9 [00:01<00:00,  5.62batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 29: 100%|██████████| 35/35 [00:06<00:00,  5.82batch/s, Точность=15.9, Средняя потеря=1.94]
# Тестирование 29: 100%|██████████| 9/9 [00:01<00:00,  5.64batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 30: 100%|██████████| 35/35 [00:06<00:00,  5.75batch/s, Точность=16.4, Средняя потеря=1.94]
# Тестирование 30: 100%|██████████| 9/9 [00:01<00:00,  5.59batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 31: 100%|██████████| 35/35 [00:06<00:00,  5.77batch/s, Точность=16.7, Средняя потеря=1.94]
# Тестирование 31: 100%|██████████| 9/9 [00:01<00:00,  5.68batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 32: 100%|██████████| 35/35 [00:06<00:00,  5.74batch/s, Точность=16.4, Средняя потеря=1.94]
# Тестирование 32: 100%|██████████| 9/9 [00:01<00:00,  5.64batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 33: 100%|██████████| 35/35 [00:06<00:00,  5.72batch/s, Точность=17.5, Средняя потеря=1.94]
# Тестирование 33: 100%|██████████| 9/9 [00:01<00:00,  5.65batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 34: 100%|██████████| 35/35 [00:06<00:00,  5.71batch/s, Точность=16.2, Средняя потеря=1.94]
# Тестирование 34: 100%|██████████| 9/9 [00:01<00:00,  5.62batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 35: 100%|██████████| 35/35 [00:06<00:00,  5.70batch/s, Точность=16.9, Средняя потеря=1.94]
# Тестирование 35: 100%|██████████| 9/9 [00:01<00:00,  5.66batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 36: 100%|██████████| 35/35 [00:06<00:00,  5.83batch/s, Точность=16.8, Средняя потеря=1.94]
# Тестирование 36: 100%|██████████| 9/9 [00:01<00:00,  5.62batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 37: 100%|██████████| 35/35 [00:06<00:00,  5.79batch/s, Точность=16.7, Средняя потеря=1.94]
# Тестирование 37: 100%|██████████| 9/9 [00:01<00:00,  5.64batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 38: 100%|██████████| 35/35 [00:06<00:00,  5.73batch/s, Точность=17.2, Средняя потеря=1.94]
# Тестирование 38: 100%|██████████| 9/9 [00:01<00:00,  5.68batch/s, Точность=17.1, Средняя потеря=1.94]
# Эпоха 39: 100%|██████████| 35/35 [00:06<00:00,  5.83batch/s, Точность=17.2, Средняя потеря=1.94]
# Тестирование 39: 100%|██████████| 9/9 [00:01<00:00,  5.69batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 40: 100%|██████████| 35/35 [00:06<00:00,  5.79batch/s, Точность=16.3, Средняя потеря=1.94]
# Тестирование 40: 100%|██████████| 9/9 [00:01<00:00,  5.60batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 41: 100%|██████████| 35/35 [00:06<00:00,  5.81batch/s, Точность=16.9, Средняя потеря=1.94]
# Тестирование 41: 100%|██████████| 9/9 [00:01<00:00,  5.67batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 42: 100%|██████████| 35/35 [00:06<00:00,  5.65batch/s, Точность=16.3, Средняя потеря=1.94]
# Тестирование 42: 100%|██████████| 9/9 [00:01<00:00,  5.25batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 43: 100%|██████████| 35/35 [00:06<00:00,  5.78batch/s, Точность=16.4, Средняя потеря=1.94]
# Тестирование 43: 100%|██████████| 9/9 [00:01<00:00,  5.65batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 44: 100%|██████████| 35/35 [00:06<00:00,  5.69batch/s, Точность=17.5, Средняя потеря=1.94]
# Тестирование 44: 100%|██████████| 9/9 [00:01<00:00,  5.66batch/s, Точность=15, Средняя потеря=1.94]
# Эпоха 45: 100%|██████████| 35/35 [00:06<00:00,  5.05batch/s, Точность=16.5, Средняя потеря=1.94]
# Тестирование 45: 100%|██████████| 9/9 [00:01<00:00,  5.62batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 46: 100%|██████████| 35/35 [00:06<00:00,  5.77batch/s, Точность=16.8, Средняя потеря=1.94]
# Тестирование 46: 100%|██████████| 9/9 [00:01<00:00,  5.46batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 47: 100%|██████████| 35/35 [00:06<00:00,  5.78batch/s, Точность=16.9, Средняя потеря=1.94]
# Тестирование 47: 100%|██████████| 9/9 [00:01<00:00,  5.65batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 48: 100%|██████████| 35/35 [00:06<00:00,  5.69batch/s, Точность=16.9, Средняя потеря=1.94]
# Тестирование 48: 100%|██████████| 9/9 [00:01<00:00,  5.52batch/s, Точность=16.4, Средняя потеря=1.94]
# Ранняя остановка на эпохе 48 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_lstm_best = LSTMClassifier(num_classes = 7, model_name='jina', pooling=None).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "LSTMClassifier_jina_38_17.14_checkpoint.pth"))
model_lstm_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# <All keys matched successfully>

# %%
evaluate_metrics(model_lstm_best, test_dataloader)
# Out:
# {'uar': 0.15303030303030302,
#  'war': 0.17142857142857143,
#  'mf1': 0.07817525581613567,
#  'wf1': 0.08698413879480059}

# %% [markdown]
# #### LSTM + xlm-roberta-base with mean pooling

# %%
lstm = LSTMClassifier(num_classes = 7, model_name='xlm-roberta-base', pooling='mean', input_size=768).to(device)
optimizer = optim.AdamW(params = lstm.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(lstm, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:01<00:00, 20.06batch/s, Точность=13.7, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:00<00:00, 22.55batch/s, Точность=13.6, Средняя потеря=1.95]
# Эпоха 2: 100%|██████████| 35/35 [00:01<00:00, 22.39batch/s, Точность=13.7, Средняя потеря=1.95]
# Тестирование 2: 100%|██████████| 9/9 [00:00<00:00, 23.68batch/s, Точность=13.6, Средняя потеря=1.95]
# Эпоха 3: 100%|██████████| 35/35 [00:01<00:00, 22.65batch/s, Точность=13.7, Средняя потеря=1.95]
# Тестирование 3: 100%|██████████| 9/9 [00:00<00:00, 23.72batch/s, Точность=13.6, Средняя потеря=1.95]
# Эпоха 4: 100%|██████████| 35/35 [00:02<00:00, 15.42batch/s, Точность=13.7, Средняя потеря=1.95]
# Тестирование 4: 100%|██████████| 9/9 [00:00<00:00, 16.33batch/s, Точность=13.6, Средняя потеря=1.95]
# Эпоха 5: 100%|██████████| 35/35 [00:01<00:00, 21.23batch/s, Точность=13.7, Средняя потеря=1.95]
# Тестирование 5: 100%|██████████| 9/9 [00:00<00:00, 23.57batch/s, Точность=13.6, Средняя потеря=1.95]
# Эпоха 6: 100%|██████████| 35/35 [00:01<00:00, 21.73batch/s, Точность=13.7, Средняя потеря=1.95]
# Тестирование 6: 100%|██████████| 9/9 [00:00<00:00, 23.76batch/s, Точность=13.6, Средняя потеря=1.95]
# Эпоха 7: 100%|██████████| 35/35 [00:01<00:00, 22.78batch/s, Точность=14.3, Средняя потеря=1.95]
# Тестирование 7: 100%|██████████| 9/9 [00:00<00:00, 23.37batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 8: 100%|██████████| 35/35 [00:01<00:00, 23.03batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 8: 100%|██████████| 9/9 [00:00<00:00, 23.79batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 9: 100%|██████████| 35/35 [00:01<00:00, 22.61batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 9: 100%|██████████| 9/9 [00:00<00:00, 23.51batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 10: 100%|██████████| 35/35 [00:01<00:00, 22.65batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 10: 100%|██████████| 9/9 [00:00<00:00, 23.75batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 11: 100%|██████████| 35/35 [00:01<00:00, 22.11batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 11: 100%|██████████| 9/9 [00:00<00:00, 23.66batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 12: 100%|██████████| 35/35 [00:01<00:00, 22.61batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 12: 100%|██████████| 9/9 [00:00<00:00, 23.44batch/s, Точность=16.1, Средняя потеря=1.95]
# Эпоха 13: 100%|██████████| 35/35 [00:01<00:00, 22.35batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 13: 100%|██████████| 9/9 [00:00<00:00, 23.86batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 14: 100%|██████████| 35/35 [00:01<00:00, 22.48batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 14: 100%|██████████| 9/9 [00:00<00:00, 23.41batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 15: 100%|██████████| 35/35 [00:01<00:00, 22.44batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 15: 100%|██████████| 9/9 [00:00<00:00, 23.67batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 16: 100%|██████████| 35/35 [00:01<00:00, 21.80batch/s, Точность=15.9, Средняя потеря=1.94]
# Тестирование 16: 100%|██████████| 9/9 [00:00<00:00, 23.75batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 17: 100%|██████████| 35/35 [00:01<00:00, 22.61batch/s, Точность=15.9, Средняя потеря=1.94]
# Тестирование 17: 100%|██████████| 9/9 [00:00<00:00, 23.56batch/s, Точность=16.1, Средняя потеря=1.94]
# Ранняя остановка на эпохе 17 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_lstm_best = LSTMClassifier(num_classes = 7, model_name='xlm-roberta-base', pooling='mean', input_size=768).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "LSTMClassifier_xlm-roberta-base_7_16.07_checkpoint.pth"))
model_lstm_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_lstm_best, test_dataloader)
# Out:
# {'uar': 0.14285714285714285,
#  'war': 0.16071428571428573,
#  'mf1': 0.03968253968253969,
#  'wf1': 0.044642857142857144}

# %% [markdown]
# #### LSTM + xlm-roberta-base

# %%
lstm = LSTMClassifier(num_classes = 7, model_name='xlm-roberta-base', pooling=None, input_size=768).to(device)
optimizer = optim.AdamW(params = lstm.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(lstm, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:22<00:00,  1.55batch/s, Точность=11.7, Средняя потеря=1.97]
# Тестирование 1: 100%|██████████| 9/9 [00:05<00:00,  1.60batch/s, Точность=11.4, Средняя потеря=1.97]
# Эпоха 2: 100%|██████████| 35/35 [00:23<00:00,  1.51batch/s, Точность=11.7, Средняя потеря=1.97]
# Тестирование 2: 100%|██████████| 9/9 [00:05<00:00,  1.61batch/s, Точность=11.4, Средняя потеря=1.96]
# Эпоха 3: 100%|██████████| 35/35 [00:22<00:00,  1.58batch/s, Точность=11.7, Средняя потеря=1.96]
# Тестирование 3: 100%|██████████| 9/9 [00:05<00:00,  1.59batch/s, Точность=11.4, Средняя потеря=1.96]
# Эпоха 4: 100%|██████████| 35/35 [00:22<00:00,  1.56batch/s, Точность=11.7, Средняя потеря=1.96]
# Тестирование 4: 100%|██████████| 9/9 [00:05<00:00,  1.60batch/s, Точность=11.4, Средняя потеря=1.96]
# Эпоха 5: 100%|██████████| 35/35 [00:22<00:00,  1.57batch/s, Точность=11.7, Средняя потеря=1.96]
# Тестирование 5: 100%|██████████| 9/9 [00:05<00:00,  1.59batch/s, Точность=11.4, Средняя потеря=1.96]
# Эпоха 6: 100%|██████████| 35/35 [00:21<00:00,  1.61batch/s, Точность=11.7, Средняя потеря=1.96]
# Тестирование 6: 100%|██████████| 9/9 [00:05<00:00,  1.62batch/s, Точность=11.4, Средняя потеря=1.95]
# Эпоха 7: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=13, Средняя потеря=1.95]
# Тестирование 7: 100%|██████████| 9/9 [00:05<00:00,  1.65batch/s, Точность=13.2, Средняя потеря=1.95]
# Эпоха 8: 100%|██████████| 35/35 [00:21<00:00,  1.61batch/s, Точность=13.1, Средняя потеря=1.95]
# Тестирование 8: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=13.2, Средняя потеря=1.95]
# Эпоха 9: 100%|██████████| 35/35 [00:21<00:00,  1.61batch/s, Точность=13.4, Средняя потеря=1.95]
# Тестирование 9: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=15.4, Средняя потеря=1.95]
# Эпоха 10: 100%|██████████| 35/35 [00:21<00:00,  1.59batch/s, Точность=15.9, Средняя потеря=1.95]
# Тестирование 10: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 11: 100%|██████████| 35/35 [00:21<00:00,  1.61batch/s, Точность=15.9, Средняя потеря=1.94]
# Тестирование 11: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 12: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=15.7, Средняя потеря=1.94]
# Тестирование 12: 100%|██████████| 9/9 [00:05<00:00,  1.61batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 13: 100%|██████████| 35/35 [00:21<00:00,  1.61batch/s, Точность=16.1, Средняя потеря=1.94]
# Тестирование 13: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 14: 100%|██████████| 35/35 [00:21<00:00,  1.61batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 14: 100%|██████████| 9/9 [00:05<00:00,  1.64batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 15: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=15.9, Средняя потеря=1.94]
# Тестирование 15: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 16: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 16: 100%|██████████| 9/9 [00:05<00:00,  1.62batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 17: 100%|██████████| 35/35 [00:22<00:00,  1.59batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 17: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 18: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=15.9, Средняя потеря=1.94]
# Тестирование 18: 100%|██████████| 9/9 [00:05<00:00,  1.62batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 19: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 19: 100%|██████████| 9/9 [00:05<00:00,  1.64batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 20: 100%|██████████| 35/35 [00:21<00:00,  1.61batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 20: 100%|██████████| 9/9 [00:05<00:00,  1.64batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 21: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 21: 100%|██████████| 9/9 [00:05<00:00,  1.64batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 22: 100%|██████████| 35/35 [00:21<00:00,  1.59batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 22: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 23: 100%|██████████| 35/35 [00:21<00:00,  1.61batch/s, Точность=15.9, Средняя потеря=1.94]
# Тестирование 23: 100%|██████████| 9/9 [00:05<00:00,  1.62batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 24: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=15.8, Средняя потеря=1.94]
# Тестирование 24: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 25: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 25: 100%|██████████| 9/9 [00:05<00:00,  1.62batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 26: 100%|██████████| 35/35 [00:21<00:00,  1.60batch/s, Точность=16, Средняя потеря=1.94]
# Тестирование 26: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 27: 100%|██████████| 35/35 [00:21<00:00,  1.59batch/s, Точность=16.3, Средняя потеря=1.94]
# Тестирование 27: 100%|██████████| 9/9 [00:05<00:00,  1.63batch/s, Точность=16.8, Средняя потеря=1.94]
# Ранняя остановка на эпохе 27 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_lstm_best = LSTMClassifier(num_classes = 7, model_name='xlm-roberta-base', pooling=None, input_size=768).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "LSTMClassifier_xlm-roberta-base_emb_17_16.79_checkpoint.pth"))
model_lstm_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_lstm_best, test_dataloader)
# Out:
# {'uar': 0.1497835497835498,
#  'war': 0.16785714285714284,
#  'mf1': 0.07609653197888491,
#  'wf1': 0.0846473048678931,
#  'accuracy': 0.16785714285714284}

# %% [markdown]
# #### LSTM + canine-c with mean pooling

# %%
lstm = LSTMClassifier(num_classes = 7, model_name='canine-c', pooling='mean', input_size=768).to(device)
optimizer = optim.AdamW(params = lstm.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(lstm, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:02<00:00, 14.20batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 1: 100%|██████████| 9/9 [00:00<00:00, 14.25batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 2: 100%|██████████| 35/35 [00:02<00:00, 14.58batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 2: 100%|██████████| 9/9 [00:00<00:00, 14.64batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 3: 100%|██████████| 35/35 [00:02<00:00, 14.45batch/s, Точность=14.2, Средняя потеря=1.95]
# Тестирование 3: 100%|██████████| 9/9 [00:00<00:00, 14.30batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 4: 100%|██████████| 35/35 [00:02<00:00, 14.31batch/s, Точность=15.6, Средняя потеря=1.95]
# Тестирование 4: 100%|██████████| 9/9 [00:00<00:00, 14.29batch/s, Точность=15, Средняя потеря=1.95]
# Эпоха 5: 100%|██████████| 35/35 [00:02<00:00, 14.45batch/s, Точность=16.8, Средняя потеря=1.95]
# Тестирование 5: 100%|██████████| 9/9 [00:00<00:00, 14.27batch/s, Точность=15.4, Средняя потеря=1.95]
# Эпоха 6: 100%|██████████| 35/35 [00:02<00:00, 14.34batch/s, Точность=15.8, Средняя потеря=1.95]
# Тестирование 6: 100%|██████████| 9/9 [00:00<00:00, 13.99batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 7: 100%|██████████| 35/35 [00:02<00:00, 14.08batch/s, Точность=18.4, Средняя потеря=1.94]
# Тестирование 7: 100%|██████████| 9/9 [00:00<00:00, 14.31batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 8: 100%|██████████| 35/35 [00:02<00:00, 14.41batch/s, Точность=17.7, Средняя потеря=1.94]
# Тестирование 8: 100%|██████████| 9/9 [00:00<00:00, 14.13batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 9: 100%|██████████| 35/35 [00:02<00:00, 14.24batch/s, Точность=18.7, Средняя потеря=1.94]
# Тестирование 9: 100%|██████████| 9/9 [00:00<00:00, 14.29batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 10: 100%|██████████| 35/35 [00:02<00:00, 14.35batch/s, Точность=18.6, Средняя потеря=1.94]
# Тестирование 10: 100%|██████████| 9/9 [00:00<00:00, 14.28batch/s, Точность=18.2, Средняя потеря=1.94]
# Эпоха 11: 100%|██████████| 35/35 [00:02<00:00, 14.22batch/s, Точность=19, Средняя потеря=1.94]
# Тестирование 11: 100%|██████████| 9/9 [00:00<00:00, 14.27batch/s, Точность=18.6, Средняя потеря=1.94]
# Эпоха 12: 100%|██████████| 35/35 [00:02<00:00, 14.31batch/s, Точность=18.6, Средняя потеря=1.94]
# Тестирование 12: 100%|██████████| 9/9 [00:00<00:00, 14.27batch/s, Точность=18.2, Средняя потеря=1.94]
# Эпоха 13: 100%|██████████| 35/35 [00:02<00:00, 14.24batch/s, Точность=18.3, Средняя потеря=1.94]
# Тестирование 13: 100%|██████████| 9/9 [00:00<00:00, 14.23batch/s, Точность=17.1, Средняя потеря=1.94]
# Эпоха 14: 100%|██████████| 35/35 [00:02<00:00, 14.34batch/s, Точность=17.6, Средняя потеря=1.94]
# Тестирование 14: 100%|██████████| 9/9 [00:00<00:00, 14.31batch/s, Точность=16.8, Средняя потеря=1.94]
# Эпоха 15: 100%|██████████| 35/35 [00:02<00:00, 14.23batch/s, Точность=17.8, Средняя потеря=1.94]
# Тестирование 15: 100%|██████████| 9/9 [00:00<00:00, 13.19batch/s, Точность=18.6, Средняя потеря=1.94]
# Эпоха 16: 100%|██████████| 35/35 [00:02<00:00, 14.12batch/s, Точность=18.6, Средняя потеря=1.94]
# Тестирование 16: 100%|██████████| 9/9 [00:00<00:00, 14.28batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 17: 100%|██████████| 35/35 [00:02<00:00, 14.42batch/s, Точность=18.6, Средняя потеря=1.94]
# Тестирование 17: 100%|██████████| 9/9 [00:00<00:00, 14.28batch/s, Точность=15.7, Средняя потеря=1.94]
# Эпоха 18: 100%|██████████| 35/35 [00:02<00:00, 14.18batch/s, Точность=17.7, Средняя потеря=1.94]
# Тестирование 18: 100%|██████████| 9/9 [00:00<00:00, 14.27batch/s, Точность=14.6, Средняя потеря=1.94]
# Эпоха 19: 100%|██████████| 35/35 [00:02<00:00, 14.02batch/s, Точность=17.9, Средняя потеря=1.94]
# Тестирование 19: 100%|██████████| 9/9 [00:00<00:00, 14.25batch/s, Точность=14.6, Средняя потеря=1.94]
# Эпоха 20: 100%|██████████| 35/35 [00:02<00:00, 14.27batch/s, Точность=17.4, Средняя потеря=1.94]
# Тестирование 20: 100%|██████████| 9/9 [00:00<00:00, 14.22batch/s, Точность=15, Средняя потеря=1.94]
# Эпоха 21: 100%|██████████| 35/35 [00:02<00:00, 14.30batch/s, Точность=16.8, Средняя потеря=1.94]
# Тестирование 21: 100%|██████████| 9/9 [00:00<00:00, 14.19batch/s, Точность=15, Средняя потеря=1.94]
# Ранняя остановка на эпохе 21 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_lstm_best = LSTMClassifier(num_classes = 7, model_name='canine-c', pooling='mean', input_size=768).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "LSTMClassifier_canine-c_11_18.57_checkpoint.pth"))
model_lstm_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_lstm_best, test_dataloader)
# Out:
# {'uar': 0.1688311688311688,
#  'war': 0.18571428571428572,
#  'mf1': 0.08490292668791655,
#  'wf1': 0.0933932193567082}

# %% [markdown]
# #### LSTM + canine-c

# %%
lstm = LSTMClassifier(num_classes = 7, model_name='canine-c', pooling=None, input_size=768).to(device)
optimizer = optim.AdamW(params = lstm.parameters(), lr = LEARNING_RATE)
loss_fn = nn.CrossEntropyLoss()
trainer = ModelTrainer(lstm, train_dataloader, test_dataloader, DEVICE, 50, ROUND_LOSS, ROUND_ACC, optimizer, loss_fn, patience=10)
trainer.train(PATH_TO_MODEL)
# Out:
# Эпоха 1: 100%|██████████| 35/35 [00:03<00:00, 10.75batch/s, Точность=14.9, Средняя потеря=1.96]
# Тестирование 1: 100%|██████████| 9/9 [00:00<00:00, 11.09batch/s, Точность=13.9, Средняя потеря=1.96]
# Эпоха 2: 100%|██████████| 35/35 [00:03<00:00, 11.03batch/s, Точность=16.4, Средняя потеря=1.95]
# Тестирование 2: 100%|██████████| 9/9 [00:00<00:00, 11.00batch/s, Точность=15, Средняя потеря=1.95]
# Эпоха 3: 100%|██████████| 35/35 [00:03<00:00, 11.00batch/s, Точность=16.8, Средняя потеря=1.94]
# Тестирование 3: 100%|██████████| 9/9 [00:00<00:00, 10.67batch/s, Точность=14.3, Средняя потеря=1.95]
# Эпоха 4: 100%|██████████| 35/35 [00:03<00:00, 11.08batch/s, Точность=18, Средняя потеря=1.94]
# Тестирование 4: 100%|██████████| 9/9 [00:00<00:00, 11.06batch/s, Точность=13.6, Средняя потеря=1.94]
# Эпоха 5: 100%|██████████| 35/35 [00:03<00:00, 10.96batch/s, Точность=20.2, Средняя потеря=1.93]
# Тестирование 5: 100%|██████████| 9/9 [00:00<00:00, 11.09batch/s, Точность=16.1, Средняя потеря=1.94]
# Эпоха 6: 100%|██████████| 35/35 [00:03<00:00, 10.97batch/s, Точность=21.8, Средняя потеря=1.92]
# Тестирование 6: 100%|██████████| 9/9 [00:00<00:00, 11.06batch/s, Точность=16.4, Средняя потеря=1.94]
# Эпоха 7: 100%|██████████| 35/35 [00:03<00:00, 11.04batch/s, Точность=22.7, Средняя потеря=1.92]
# Тестирование 7: 100%|██████████| 9/9 [00:00<00:00, 10.99batch/s, Точность=17.1, Средняя потеря=1.93]
# Эпоха 8: 100%|██████████| 35/35 [00:03<00:00, 10.96batch/s, Точность=22.9, Средняя потеря=1.91]
# Тестирование 8: 100%|██████████| 9/9 [00:00<00:00, 10.80batch/s, Точность=18.6, Средняя потеря=1.93]
# Эпоха 9: 100%|██████████| 35/35 [00:03<00:00, 10.99batch/s, Точность=24.6, Средняя потеря=1.9]
# Тестирование 9: 100%|██████████| 9/9 [00:00<00:00, 11.01batch/s, Точность=20, Средняя потеря=1.93]
# Эпоха 10: 100%|██████████| 35/35 [00:03<00:00, 10.99batch/s, Точность=24.5, Средняя потеря=1.89]
# Тестирование 10: 100%|██████████| 9/9 [00:00<00:00, 10.94batch/s, Точность=20.7, Средняя потеря=1.93]
# Эпоха 11: 100%|██████████| 35/35 [00:03<00:00, 10.99batch/s, Точность=25.1, Средняя потеря=1.88]
# Тестирование 11: 100%|██████████| 9/9 [00:00<00:00, 11.13batch/s, Точность=20, Средняя потеря=1.92]
# Эпоха 12: 100%|██████████| 35/35 [00:03<00:00, 10.75batch/s, Точность=25.7, Средняя потеря=1.86]
# Тестирование 12: 100%|██████████| 9/9 [00:00<00:00, 10.69batch/s, Точность=18.9, Средняя потеря=1.92]
# Эпоха 13: 100%|██████████| 35/35 [00:03<00:00, 11.20batch/s, Точность=26.2, Средняя потеря=1.85]
# Тестирование 13: 100%|██████████| 9/9 [00:00<00:00, 10.92batch/s, Точность=21.8, Средняя потеря=1.92]
# Эпоха 14: 100%|██████████| 35/35 [00:03<00:00, 10.95batch/s, Точность=27.5, Средняя потеря=1.84]
# Тестирование 14: 100%|██████████| 9/9 [00:00<00:00, 11.03batch/s, Точность=21.4, Средняя потеря=1.92]
# Эпоха 15: 100%|██████████| 35/35 [00:03<00:00, 10.99batch/s, Точность=29.1, Средняя потеря=1.82]
# Тестирование 15: 100%|██████████| 9/9 [00:00<00:00, 11.01batch/s, Точность=22.5, Средняя потеря=1.92]
# Эпоха 16: 100%|██████████| 35/35 [00:03<00:00, 11.00batch/s, Точность=30.5, Средняя потеря=1.81]
# Тестирование 16: 100%|██████████| 9/9 [00:00<00:00, 11.02batch/s, Точность=21.8, Средняя потеря=1.93]
# Эпоха 17: 100%|██████████| 35/35 [00:03<00:00, 10.96batch/s, Точность=31.9, Средняя потеря=1.79]
# Тестирование 17: 100%|██████████| 9/9 [00:00<00:00, 10.94batch/s, Точность=21.8, Средняя потеря=1.93]
# Эпоха 18: 100%|██████████| 35/35 [00:03<00:00, 10.74batch/s, Точность=34.2, Средняя потеря=1.77]
# Тестирование 18: 100%|██████████| 9/9 [00:00<00:00, 11.05batch/s, Точность=21.4, Средняя потеря=1.93]
# Эпоха 19: 100%|██████████| 35/35 [00:03<00:00, 11.11batch/s, Точность=34.4, Средняя потеря=1.75]
# Тестирование 19: 100%|██████████| 9/9 [00:00<00:00, 10.94batch/s, Точность=20.4, Средняя потеря=1.93]
# Эпоха 20: 100%|██████████| 35/35 [00:03<00:00, 11.38batch/s, Точность=36.6, Средняя потеря=1.72]
# Тестирование 20: 100%|██████████| 9/9 [00:00<00:00, 11.54batch/s, Точность=22.1, Средняя потеря=1.94]
# Эпоха 21: 100%|██████████| 35/35 [00:03<00:00, 10.65batch/s, Точность=36.1, Средняя потеря=1.71]
# Тестирование 21: 100%|██████████| 9/9 [00:00<00:00, 10.72batch/s, Точность=19.6, Средняя потеря=1.94]
# Эпоха 22: 100%|██████████| 35/35 [00:03<00:00, 11.07batch/s, Точность=38.8, Средняя потеря=1.69]
# Тестирование 22: 100%|██████████| 9/9 [00:01<00:00,  7.27batch/s, Точность=20.7, Средняя потеря=1.94]
# Эпоха 23: 100%|██████████| 35/35 [00:03<00:00,  8.95batch/s, Точность=40.5, Средняя потеря=1.66]
# Тестирование 23: 100%|██████████| 9/9 [00:00<00:00, 10.49batch/s, Точность=22.1, Средняя потеря=1.95]
# Эпоха 24: 100%|██████████| 35/35 [00:03<00:00, 10.94batch/s, Точность=41.2, Средняя потеря=1.63]
# Тестирование 24: 100%|██████████| 9/9 [00:00<00:00, 10.71batch/s, Точность=22.9, Средняя потеря=1.96]
# Эпоха 25: 100%|██████████| 35/35 [00:03<00:00, 10.85batch/s, Точность=42.5, Средняя потеря=1.61]
# Тестирование 25: 100%|██████████| 9/9 [00:00<00:00, 11.05batch/s, Точность=22.5, Средняя потеря=1.96]
# Эпоха 26: 100%|██████████| 35/35 [00:03<00:00, 11.04batch/s, Точность=40.7, Средняя потеря=1.62]
# Тестирование 26: 100%|██████████| 9/9 [00:00<00:00, 11.01batch/s, Точность=21.1, Средняя потеря=1.97]
# Эпоха 27: 100%|██████████| 35/35 [00:03<00:00, 10.96batch/s, Точность=42.3, Средняя потеря=1.6]
# Тестирование 27: 100%|██████████| 9/9 [00:00<00:00, 11.04batch/s, Точность=22.9, Средняя потеря=1.98]
# Эпоха 28: 100%|██████████| 35/35 [00:03<00:00, 10.95batch/s, Точность=44.2, Средняя потеря=1.56]
# Тестирование 28: 100%|██████████| 9/9 [00:00<00:00, 10.80batch/s, Точность=19.6, Средняя потеря=1.99]
# Эпоха 29: 100%|██████████| 35/35 [00:03<00:00, 11.07batch/s, Точность=46.6, Средняя потеря=1.53]
# Тестирование 29: 100%|██████████| 9/9 [00:00<00:00, 11.04batch/s, Точность=20.7, Средняя потеря=1.98]
# Эпоха 30: 100%|██████████| 35/35 [00:03<00:00, 10.91batch/s, Точность=48, Средняя потеря=1.51]
# Тестирование 30: 100%|██████████| 9/9 [00:00<00:00, 11.00batch/s, Точность=20.4, Средняя потеря=2]
# Эпоха 31: 100%|██████████| 35/35 [00:03<00:00, 10.86batch/s, Точность=48.5, Средняя потеря=1.48]
# Тестирование 31: 100%|██████████| 9/9 [00:00<00:00, 10.96batch/s, Точность=21.4, Средняя потеря=1.99]
# Эпоха 32: 100%|██████████| 35/35 [00:03<00:00, 11.54batch/s, Точность=49.8, Средняя потеря=1.46]
# Тестирование 32: 100%|██████████| 9/9 [00:00<00:00, 10.71batch/s, Точность=21.4, Средняя потеря=2.01]
# Эпоха 33: 100%|██████████| 35/35 [00:03<00:00, 11.06batch/s, Точность=50.8, Средняя потеря=1.43]
# Тестирование 33: 100%|██████████| 9/9 [00:00<00:00, 11.04batch/s, Точность=18.6, Средняя потеря=2.03]
# Эпоха 34: 100%|██████████| 35/35 [00:03<00:00, 10.75batch/s, Точность=53, Средняя потеря=1.42]
# Тестирование 34: 100%|██████████| 9/9 [00:00<00:00, 11.08batch/s, Точность=21.8, Средняя потеря=2.02]
# Ранняя остановка на эпохе 34 из-за отсутствия улучшения точности на тестовой выборке

# %%
model_lstm_best = LSTMClassifier(num_classes = 7, model_name='canine-c', pooling=None, input_size=768).to(device)
checkpoint = torch.load(os.path.join(PATH_TO_MODEL, "LSTMClassifier_canine-c_24_22.86_checkpoint.pth"))
model_lstm_best.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
evaluate_metrics(model_lstm_best, test_dataloader)
# Out:
# {'uar': 0.2166700150252782,
#  'war': 0.22857142857142856,
#  'mf1': 0.19828189203583818,
#  'wf1': 0.2060930750899293}
